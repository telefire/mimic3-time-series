# %%
! python phenotyping/main.py --network models/lstm.py --dim 256 --timestep 1.0 --depth 1 --dropout 0.3 --mode test --batch_size 8 --load_state phenotyping/keras_states/k_lstm.n256.d0.3.dep1.bs8.ts1.0.epoch18.test0.35045282521.state
# Out:
# phenotyping/main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Using TensorFlow backend.
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='phenotyping/../../data/phenotyping/', depth=1, dim=256, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='phenotyping/keras_states/k_lstm.n256.d0.3.dep1.bs8.ts1.0.epoch18.test0.35045282521.state', lr=0.001, mode='test', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='.', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, target_repl_coef=0.0, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ==> not used params in network class: dict_keys(['batch_size', 'beta_1', 'data', 'epochs', 'imputation', 'l1', 'l2', 'load_state', 'lr', 'mode', 'network', 'normalizer_state', 'optimizer', 'output_dir', 'prefix', 'save_every', 'size_coef', 'small_part', 'target_repl_coef', 'timestep', 'verbose', 'header'])
# WARNING:tensorflow:From /home/yanke/anaconda2/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/yanke/anaconda2/envs/py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# ==> model.final_name: k_lstm.n256.d0.3.dep1.bs8.ts1.0
# ==> compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# X (InputLayer)               (None, None, 76)          0
# _________________________________________________________________
# masking_1 (Masking)          (None, None, 76)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               340992
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                6425
# =================================================================
# Total params: 347,417
# Trainable params: 347,417
# Non-trainable params: 0
# _________________________________________________________________
# 2019-07-23 16:30:21.137839: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-23 16:30:21.158054: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3696000000 Hz
# 2019-07-23 16:30:21.158615: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55b3ab2a3d10 executing computations on platform Host. Devices:
# 2019-07-23 16:30:21.158632: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-07-23 16:30:21.222259: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-07-23 16:30:21.222963: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55b3ab237260 executing computations on platform CUDA. Devices:
# 2019-07-23 16:30:21.222977: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2019-07-23 16:30:21.223078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.683
# pciBusID: 0000:02:00.0
# totalMemory: 10.92GiB freeMemory: 10.64GiB
# 2019-07-23 16:30:21.223088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-07-23 16:30:21.224105: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-07-23 16:30:21.224115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-07-23 16:30:21.224120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-07-23 16:30:21.224187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10349 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# 2019-07-23 16:35:18.091151: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ROC AUC scores for labels: [0.80028945 0.91546843 0.75769125 0.67031246 0.7611359  0.67855676
#  0.71256578 0.71821923 0.74795166 0.77931974 0.87345627 0.78945944
#  0.71836911 0.66681689 0.73912642 0.74029418 0.73775067 0.75995193
#  0.67759789 0.76746645 0.69153035 0.7999143  0.90176031 0.8415699
#  0.87795356]
# ave_auc_micro = 0.8174567274721132
# ave_auc_macro = 0.7649811318624005
# ave_auc_weighted = 0.7516371700014629

# %%
! python phenotyping/main.py --network models/lstm.py --dim 256 --timestep 1.0 --depth 1 --dropout 0.3 --mode test --batch_size 8 --load_state phenotyping/keras_states/k_lstm.n256.d0.3.dep1.bs8.ts1.0.epoch15.test0.348429243492.state
# Out:
# phenotyping/main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Using TensorFlow backend.
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='phenotyping/../../data/phenotyping/', depth=1, dim=256, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='phenotyping/keras_states/k_lstm.n256.d0.3.dep1.bs8.ts1.0.epoch15.test0.348429243492.state', lr=0.001, mode='test', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='.', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, target_repl_coef=0.0, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ==> not used params in network class: dict_keys(['batch_size', 'beta_1', 'data', 'epochs', 'imputation', 'l1', 'l2', 'load_state', 'lr', 'mode', 'network', 'normalizer_state', 'optimizer', 'output_dir', 'prefix', 'save_every', 'size_coef', 'small_part', 'target_repl_coef', 'timestep', 'verbose', 'header'])
# WARNING:tensorflow:From /home/yanke/anaconda2/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/yanke/anaconda2/envs/py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# ==> model.final_name: k_lstm.n256.d0.3.dep1.bs8.ts1.0
# ==> compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# X (InputLayer)               (None, None, 76)          0
# _________________________________________________________________
# masking_1 (Masking)          (None, None, 76)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               340992
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                6425
# =================================================================
# Total params: 347,417
# Trainable params: 347,417
# Non-trainable params: 0
# _________________________________________________________________
# 2019-07-23 16:35:36.064984: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-23 16:35:36.089987: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3696000000 Hz
# 2019-07-23 16:35:36.090432: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x559f7ef48870 executing computations on platform Host. Devices:
# 2019-07-23 16:35:36.090448: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-07-23 16:35:36.150757: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-07-23 16:35:36.151513: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x559f7c7531a0 executing computations on platform CUDA. Devices:
# 2019-07-23 16:35:36.151527: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2019-07-23 16:35:36.151629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.683
# pciBusID: 0000:02:00.0
# totalMemory: 10.92GiB freeMemory: 10.64GiB
# 2019-07-23 16:35:36.151640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-07-23 16:35:36.152592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-07-23 16:35:36.152602: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-07-23 16:35:36.152606: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-07-23 16:35:36.152680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10349 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# 2019-07-23 16:40:19.626564: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ROC AUC scores for labels: [0.80281827 0.91669085 0.7630518  0.66976208 0.76536913 0.68464258
#  0.71392212 0.72701117 0.74995301 0.78650084 0.86954285 0.78774208
#  0.7206328  0.67093997 0.73856786 0.74055904 0.74321642 0.7562092
#  0.68780975 0.76993272 0.70230104 0.80233979 0.90034968 0.84126611
#  0.87312745]
# ave_auc_micro = 0.8185422303662946
# ave_auc_macro = 0.7673703440783326
# ave_auc_weighted = 0.7539152684267292

# %%
! python phenotyping/main.py --network models/lstm.py --dim 256 --timestep 1.0 --depth 1 --dropout 0.3 --mode test --batch_size 8 --load_state phenotyping/keras_states/k_lstm.n256.d0.3.dep1.bs8.ts1.0.epoch21.test0.348989125666.state
# Out:
# phenotyping/main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Using TensorFlow backend.
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='phenotyping/../../data/phenotyping/', depth=1, dim=256, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='phenotyping/keras_states/k_lstm.n256.d0.3.dep1.bs8.ts1.0.epoch21.test0.348989125666.state', lr=0.001, mode='test', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='.', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, target_repl_coef=0.0, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ==> not used params in network class: dict_keys(['batch_size', 'beta_1', 'data', 'epochs', 'imputation', 'l1', 'l2', 'load_state', 'lr', 'mode', 'network', 'normalizer_state', 'optimizer', 'output_dir', 'prefix', 'save_every', 'size_coef', 'small_part', 'target_repl_coef', 'timestep', 'verbose', 'header'])
# WARNING:tensorflow:From /home/yanke/anaconda2/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/yanke/anaconda2/envs/py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# ==> model.final_name: k_lstm.n256.d0.3.dep1.bs8.ts1.0
# ==> compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# X (InputLayer)               (None, None, 76)          0
# _________________________________________________________________
# masking_1 (Masking)          (None, None, 76)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               340992
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                6425
# =================================================================
# Total params: 347,417
# Trainable params: 347,417
# Non-trainable params: 0
# _________________________________________________________________
# 2019-07-23 16:40:37.867951: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-23 16:40:37.889979: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3696000000 Hz
# 2019-07-23 16:40:37.890416: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x559d40df21a0 executing computations on platform Host. Devices:
# 2019-07-23 16:40:37.890429: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-07-23 16:40:37.946226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-07-23 16:40:37.946908: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x559d40d83ee0 executing computations on platform CUDA. Devices:
# 2019-07-23 16:40:37.946922: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2019-07-23 16:40:37.947018: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.683
# pciBusID: 0000:02:00.0
# totalMemory: 10.92GiB freeMemory: 10.64GiB
# 2019-07-23 16:40:37.947029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-07-23 16:40:37.947917: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-07-23 16:40:37.947926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-07-23 16:40:37.947932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-07-23 16:40:37.948000: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10349 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# 2019-07-23 16:45:31.833968: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ROC AUC scores for labels: [0.79981164 0.91687775 0.76844942 0.67486624 0.76396816 0.68447688
#  0.71458105 0.72879078 0.75097621 0.78788395 0.86769334 0.78826459
#  0.72152529 0.6691755  0.73903512 0.73884455 0.74004875 0.75703449
#  0.68874523 0.77223442 0.69999785 0.79916921 0.9016952  0.84285609
#  0.86892463]
# ave_auc_micro = 0.8189066013188036
# ave_auc_macro = 0.7674370539306653
# ave_auc_weighted = 0.7541849717662175
