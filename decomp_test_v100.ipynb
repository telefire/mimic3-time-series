# %%
! python decompensation/main.py --network models/lstm.py --dim 16 --timestep 1.0 --depth 2 --dropout 0.3 --mode test --batch_size 8 --load_state decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk24.test0.0783392358216.state
# Out:
# Using TensorFlow backend.
# 2019-07-23 18:44:01.012293: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='decompensation/../../data/decompensation/', deep_supervision=False, depth=2, dim=16, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk24.test0.0783392358216.state', lr=0.001, mode='test', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='.', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ...

# %%
! python decompensation/main.py --network models/lstm.py --dim 16 --timestep 1.0 --depth 2 --dropout 0.3 --mode test --batch_size 8 --load_state decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk24.test0.0783392358216.state
# Out:
# Using TensorFlow backend.
# 2019-07-24 00:22:27.782189: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='decompensation/../../data/decompensation/', deep_supervision=False, depth=2, dim=16, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk24.test0.0783392358216.state', lr=0.001, mode='test', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='.', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ...
