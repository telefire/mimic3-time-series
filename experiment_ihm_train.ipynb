# %%
# !python in_hospital_mortality/main.py --network models/lstm.py --dim 16 --timestep 1.0 --depth 2 --dropout 0.3 --mode train --batch_size 8 --output_dir in_hospital_mortality/
# Out:
# Using TensorFlow backend.
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='in_hospital_mortality/../../data/in-hospital-mortality/', deep_supervision=False, depth=2, dim=16, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='', lr=0.001, mode='train', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='in_hospital_mortality/', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, target_repl_coef=0.0, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ==> not used params in network class: ['verbose', 'timestep', 'epochs', 'header', 'prefix', 'load_state', 'optimizer', 'network', 'lr', 'output_dir', 'mode', 'size_coef', 'target_repl_coef', 'batch_size', 'data', 'save_every', 'beta_1', 'imputation', 'l2', 'small_part', 'l1', 'normalizer_state']
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# ==> model.final_name: k_lstm.n16.d0.3.dep2.bs8.ts1.0
# ==> compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# X (InputLayer)               (None, None, 76)          0
# _________________________________________________________________
# masking_1 (Masking)          (None, None, 76)          0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, None, 16)          5440
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 7,569
# Trainable params: 7,569
# Non-trainable params: 0
# _________________________________________________________________
# ==> training
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 17939 samples, validate on 3222 samples
# Epoch 1/100
# 2019-06-18 22:18:35.432990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-18 22:18:35.433639: I tensorflow/compiler/xla/service/service.cc:161] XLA service 0x55cbc9ac2910 executing computations on platform CUDA. Devices:
# 2019-06-18 22:18:35.433686: I tensorflow/compiler/xla/service/service.cc:168]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2019-06-18 22:18:35.436155: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-06-18 22:18:35.436360: I tensorflow/compiler/xla/service/service.cc:161] XLA service 0x55cbd9914a60 executing computations on platform Host. Devices:
# 2019-06-18 22:18:35.436391: I tensorflow/compiler/xla/service/service.cc:168]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-18 22:18:35.436831: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:04.0
# totalMemory: 15.75GiB freeMemory: 15.34GiB
# 2019-06-18 22:18:35.436859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-06-18 22:18:35.791627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 22:18:35.791698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-06-18 22:18:35.791710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-06-18 22:18:35.792149: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14839 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2019-06-18 22:18:39.181334: I tensorflow/stream_executor/dso_loader.cc:153] successfully opened CUDA library libcublas.so.10.0 locally
#  - 701s - loss: 0.3099 - val_loss: 0.3173
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15879    40]
#  [ 1859   161]]
# accuracy = 0.894141256809
# precision class 0 = 0.895196735859
# precision class 1 = 0.800995051861
# recall class 0 = 0.997487306595
# recall class 1 = 0.0797029733658
# AUC of ROC = 0.839312431934
# AUC of PRC = 0.467979511878
# min(+P, Se) = 0.470297029703
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2774   12]
#  [ 403   33]]
# accuracy = 0.871197998524
# precision class 0 = 0.873150765896
# precision class 1 = 0.733333349228
# recall class 0 = 0.99569272995
# recall class 1 = 0.0756880715489
# AUC of ROC = 0.810220005664
# AUC of PRC = 0.460246437123
# min(+P, Se) = 0.470319634703
#
# Epoch 00001: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch1.test0.31733254229.state
# Epoch 2/100
#  - 684s - loss: 0.2758 - val_loss: 0.3063
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15625   294]
#  [ 1513   507]]
# accuracy = 0.899269759655
# precision class 0 = 0.911716639996
# precision class 1 = 0.632958829403
# recall class 0 = 0.981531500816
# recall class 1 = 0.250990092754
# AUC of ROC = 0.856896096513
# AUC of PRC = 0.500795604153
# min(+P, Se) = 0.496544916091
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2711   75]
#  [ 316  120]]
# accuracy = 0.878646790981
# precision class 0 = 0.895606219769
# precision class 1 = 0.615384638309
# recall class 0 = 0.973079681396
# recall class 1 = 0.275229364634
# AUC of ROC = 0.828840714055
# AUC of PRC = 0.497401216007
# min(+P, Se) = 0.481400437637
#
# Epoch 00002: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch2.test0.306285566513.state
# Epoch 3/100
#  - 690s - loss: 0.2708 - val_loss: 0.3043
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15615   304]
#  [ 1477   543]]
# accuracy = 0.900719106197
# precision class 0 = 0.913585305214
# precision class 1 = 0.641086161137
# recall class 0 = 0.980903327465
# recall class 1 = 0.268811881542
# AUC of ROC = 0.861632326151
# AUC of PRC = 0.504001101365
# min(+P, Se) = 0.500495049505
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2704   82]
#  [ 311  125]]
# accuracy = 0.878026068211
# precision class 0 = 0.896849095821
# precision class 1 = 0.603864729404
# recall class 0 = 0.970567107201
# recall class 1 = 0.286697238684
# AUC of ROC = 0.831432720615
# AUC of PRC = 0.492194553266
# min(+P, Se) = 0.481651376147
#
# Epoch 00003: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch3.test0.304291173603.state
# Epoch 4/100
#  - 697s - loss: 0.2661 - val_loss: 0.3003
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15559   360]
#  [ 1404   616]]
# accuracy = 0.901666760445
# precision class 0 = 0.917231619358
# precision class 1 = 0.631147563457
# recall class 0 = 0.977385520935
# recall class 1 = 0.304950505495
# AUC of ROC = 0.866716946995
# AUC of PRC = 0.519464566782
# min(+P, Se) = 0.510638297872
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2696   90]
#  [ 299  137]]
# accuracy = 0.879267513752
# precision class 0 = 0.900166928768
# precision class 1 = 0.603524208069
# recall class 0 = 0.967695593834
# recall class 1 = 0.314220190048
# AUC of ROC = 0.836916397189
# AUC of PRC = 0.504011507558
# min(+P, Se) = 0.495454545455
#
# Epoch 00004: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch4.test0.300302931448.state
# Epoch 5/100
#  - 680s - loss: 0.2622 - val_loss: 0.2988
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15663   256]
#  [ 1477   543]]
# accuracy = 0.903394818306
# precision class 0 = 0.913827300072
# precision class 1 = 0.679599523544
# recall class 0 = 0.983918607235
# recall class 1 = 0.268811881542
# AUC of ROC = 0.871320341407
# AUC of PRC = 0.52901241943
# min(+P, Se) = 0.520039584364
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2723   63]
#  [ 311  125]]
# accuracy = 0.883923053741
# precision class 0 = 0.897495031357
# precision class 1 = 0.664893627167
# recall class 0 = 0.977386951447
# recall class 1 = 0.286697238684
# AUC of ROC = 0.837277804488
# AUC of PRC = 0.509305756397
# min(+P, Se) = 0.51376146789
#
# Epoch 00005: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch5.test0.298760735511.state
# Epoch 6/100
#  - 686s - loss: 0.2595 - val_loss: 0.2970
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15762   157]
#  [ 1560   460]]
# accuracy = 0.90428674221
# precision class 0 = 0.909941136837
# precision class 1 = 0.745542943478
# recall class 0 = 0.990137577057
# recall class 1 = 0.227722778916
# AUC of ROC = 0.875160046
# AUC of PRC = 0.540520552002
# min(+P, Se) = 0.518811881188
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2741   45]
#  [ 343   93]]
# accuracy = 0.879577875137
# precision class 0 = 0.888780832291
# precision class 1 = 0.673913061619
# recall class 0 = 0.983847796917
# recall class 1 = 0.213302746415
# AUC of ROC = 0.839897389964
# AUC of PRC = 0.525809576116
# min(+P, Se) = 0.522935779817
#
# Epoch 00006: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch6.test0.297029413454.state
# Epoch 7/100
#  - 696s - loss: 0.2588 - val_loss: 0.2958
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15582   337]
#  [ 1365   655]]
# accuracy = 0.905122935772
# precision class 0 = 0.919454753399
# precision class 1 = 0.660282254219
# recall class 0 = 0.978830337524
# recall class 1 = 0.324257433414
# AUC of ROC = 0.875695320804
# AUC of PRC = 0.542135516376
# min(+P, Se) = 0.521997034108
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2695   91]
#  [ 297  139]]
# accuracy = 0.879577875137
# precision class 0 = 0.900735318661
# precision class 1 = 0.60434782505
# recall class 0 = 0.967336654663
# recall class 1 = 0.318807333708
# AUC of ROC = 0.842577072782
# AUC of PRC = 0.523954013874
# min(+P, Se) = 0.520454545455
#
# Epoch 00007: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch7.test0.295781590234.state
# Epoch 8/100
#  - 690s - loss: 0.2563 - val_loss: 0.2928
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15653   266]
#  [ 1427   593]]
# accuracy = 0.905624628067
# precision class 0 = 0.916451990604
# precision class 1 = 0.690337598324
# recall class 0 = 0.983290433884
# recall class 1 = 0.293564349413
# AUC of ROC = 0.877745349445
# AUC of PRC = 0.54327149532
# min(+P, Se) = 0.516831683168
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2718   68]
#  [ 303  133]]
# accuracy = 0.884854137897
# precision class 0 = 0.899702072144
# precision class 1 = 0.66169154644
# recall class 0 = 0.975592255592
# recall class 1 = 0.305045872927
# AUC of ROC = 0.845181839736
# AUC of PRC = 0.528958760008
# min(+P, Se) = 0.511467889908
#
# Epoch 00008: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch8.test0.292781010918.state
# Epoch 9/100
#  - 675s - loss: 0.2541 - val_loss: 0.2917
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15711   208]
#  [ 1477   543]]
# accuracy = 0.906070590019
# precision class 0 = 0.914067983627
# precision class 1 = 0.723035931587
# recall class 0 = 0.9869338274
# recall class 1 = 0.268811881542
# AUC of ROC = 0.882153308301
# AUC of PRC = 0.554289112965
# min(+P, Se) = 0.529935675408
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2724   62]
#  [ 321  115]]
# accuracy = 0.881129741669
# precision class 0 = 0.894581258297
# precision class 1 = 0.649717509747
# recall class 0 = 0.977745890617
# recall class 1 = 0.263761460781
# AUC of ROC = 0.847466361954
# AUC of PRC = 0.53383465132
# min(+P, Se) = 0.511467889908
#
# Epoch 00009: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch9.test0.291662026042.state
# Epoch 10/100
#  - 688s - loss: 0.2541 - val_loss: 0.2945
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15690   229]
#  [ 1435   585]]
# accuracy = 0.907241225243
# precision class 0 = 0.91620439291
# precision class 1 = 0.718673229218
# recall class 0 = 0.985614657402
# recall class 1 = 0.289603948593
# AUC of ROC = 0.879928975214
# AUC of PRC = 0.555870833615
# min(+P, Se) = 0.531188118812
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2720   66]
#  [ 306  130]]
# accuracy = 0.884543776512
# precision class 0 = 0.898876428604
# precision class 1 = 0.663265287876
# recall class 0 = 0.976310133934
# recall class 1 = 0.298165142536
# AUC of ROC = 0.840483544854
# AUC of PRC = 0.522653616461
# min(+P, Se) = 0.505567928731
#
# Epoch 00010: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch10.test0.294501959464.state
# Epoch 11/100
#  - 687s - loss: 0.2509 - val_loss: 0.2924
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15721   198]
#  [ 1468   552]]
# accuracy = 0.907129704952
# precision class 0 = 0.914596557617
# precision class 1 = 0.736000001431
# recall class 0 = 0.987562060356
# recall class 1 = 0.273267328739
# AUC of ROC = 0.884633562609
# AUC of PRC = 0.560777235559
# min(+P, Se) = 0.527227722772
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2722   64]
#  [ 314  122]]
# accuracy = 0.882681548595
# precision class 0 = 0.896574437618
# precision class 1 = 0.655913949013
# recall class 0 = 0.977028012276
# recall class 1 = 0.279816508293
# AUC of ROC = 0.845579881715
# AUC of PRC = 0.529415530179
# min(+P, Se) = 0.51376146789
#
# Epoch 00011: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch11.test0.292389442389.state
# Epoch 12/100
#  - 679s - loss: 0.2478 - val_loss: 0.3184
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15853    66]
#  [ 1694   326]]
# accuracy = 0.901889741421
# precision class 0 = 0.903459310532
# precision class 1 = 0.83163267374
# recall class 0 = 0.995854020119
# recall class 1 = 0.16138613224
# AUC of ROC = 0.887189322928
# AUC of PRC = 0.561899903765
# min(+P, Se) = 0.538118811881
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2766   20]
#  [ 367   69]]
# accuracy = 0.879888296127
# precision class 0 = 0.882859885693
# precision class 1 = 0.775280892849
# recall class 0 = 0.992821276188
# recall class 1 = 0.158256873488
# AUC of ROC = 0.846148748329
# AUC of PRC = 0.523579469545
# min(+P, Se) = 0.49358974359
#
# Epoch 00012: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch12.test0.318447829107.state
# Epoch 13/100
#  - 690s - loss: 0.2477 - val_loss: 0.2909
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15753   166]
#  [ 1494   526]]
# accuracy = 0.907464206219
# precision class 0 = 0.91337621212
# precision class 1 = 0.760115623474
# recall class 0 = 0.989572227001
# recall class 1 = 0.260396033525
# AUC of ROC = 0.890076339439
# AUC of PRC = 0.572631274576
# min(+P, Se) = 0.544779811974
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2740   46]
#  [ 321  115]]
# accuracy = 0.886095583439
# precision class 0 = 0.895132303238
# precision class 1 = 0.714285731316
# recall class 0 = 0.983488857746
# recall class 1 = 0.263761460781
# AUC of ROC = 0.850141105264
# AUC of PRC = 0.534033417799
# min(+P, Se) = 0.501138952164
#
# Epoch 00013: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch13.test0.290942429497.state
# Epoch 14/100
#  - 675s - loss: 0.2469 - val_loss: 0.3012
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15740   179]
#  [ 1469   551]]
# accuracy = 0.908133089542
# precision class 0 = 0.914637684822
# precision class 1 = 0.754794538021
# recall class 0 = 0.988755583763
# recall class 1 = 0.272772282362
# AUC of ROC = 0.892143363152
# AUC of PRC = 0.575174288893
# min(+P, Se) = 0.545769421079
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2726   60]
#  [ 318  118]]
# accuracy = 0.882681548595
# precision class 0 = 0.8955321908
# precision class 1 = 0.662921369076
# recall class 0 = 0.978463768959
# recall class 1 = 0.270642191172
# AUC of ROC = 0.848304431726
# AUC of PRC = 0.528962074843
# min(+P, Se) = 0.497835497835
#
# Epoch 00014: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch14.test0.301172174141.state
# Epoch 15/100
#  - 687s - loss: 0.2451 - val_loss: 0.2917
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15792   127]
#  [ 1541   479]]
# accuracy = 0.907018244267
# precision class 0 = 0.911094427109
# precision class 1 = 0.790429055691
# recall class 0 = 0.992022097111
# recall class 1 = 0.237128719687
# AUC of ROC = 0.892278670671
# AUC of PRC = 0.579374384253
# min(+P, Se) = 0.539108910891
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2746   40]
#  [ 328  108]]
# accuracy = 0.885785222054
# precision class 0 = 0.893298625946
# precision class 1 = 0.729729712009
# recall class 0 = 0.985642492771
# recall class 1 = 0.24770642817
# AUC of ROC = 0.850667986064
# AUC of PRC = 0.536138484574
# min(+P, Se) = 0.509174311927
#
# Epoch 00015: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch15.test0.291681205608.state
# Epoch 16/100
#  - 690s - loss: 0.2446 - val_loss: 0.2921
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15693   226]
#  [ 1393   627]]
# accuracy = 0.909749686718
# precision class 0 = 0.91847127676
# precision class 1 = 0.735052764416
# recall class 0 = 0.985803127289
# recall class 1 = 0.310396045446
# AUC of ROC = 0.891369364338
# AUC of PRC = 0.580338419284
# min(+P, Se) = 0.54379020287
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2711   75]
#  [ 301  135]]
# accuracy = 0.883302271366
# precision class 0 = 0.900066375732
# precision class 1 = 0.642857134342
# recall class 0 = 0.973079681396
# recall class 1 = 0.309633016586
# AUC of ROC = 0.85002667334
# AUC of PRC = 0.529559235945
# min(+P, Se) = 0.495454545455
#
# Epoch 00016: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch16.test0.292091732256.state
# Epoch 17/100
#  - 695s - loss: 0.2430 - val_loss: 0.2867
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15736   183]
#  [ 1436   584]]
# accuracy = 0.909749686718
# precision class 0 = 0.916375517845
# precision class 1 = 0.761408090591
# recall class 0 = 0.988504290581
# recall class 1 = 0.289108902216
# AUC of ROC = 0.895463388603
# AUC of PRC = 0.588495561082
# min(+P, Se) = 0.549504950495
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2728   58]
#  [ 308  128]]
# accuracy = 0.886405944824
# precision class 0 = 0.898550748825
# precision class 1 = 0.68817204237
# recall class 0 = 0.979181647301
# recall class 1 = 0.293577969074
# AUC of ROC = 0.852646258817
# AUC of PRC = 0.538959886517
# min(+P, Se) = 0.506880733945
#
# Epoch 00017: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch17.test0.286717824707.state
# Epoch 18/100
#  - 688s - loss: 0.2424 - val_loss: 0.2917
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15782   137]
#  [ 1495   525]]
# accuracy = 0.909025013447
# precision class 0 = 0.913468778133
# precision class 1 = 0.793051362038
# recall class 0 = 0.991393923759
# recall class 1 = 0.259900987148
# AUC of ROC = 0.896737552548
# AUC of PRC = 0.589637807082
# min(+P, Se) = 0.548275862069
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2746   40]
#  [ 323  113]]
# accuracy = 0.88733702898
# precision class 0 = 0.894753992558
# precision class 1 = 0.738562107086
# recall class 0 = 0.985642492771
# recall class 1 = 0.259174317122
# AUC of ROC = 0.852326837332
# AUC of PRC = 0.543790201833
# min(+P, Se) = 0.507726269316
#
# Epoch 00018: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch18.test0.291726152613.state
# Epoch 19/100
#  - 693s - loss: 0.2436 - val_loss: 0.2865
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15708   211]
#  [ 1415   605]]
# accuracy = 0.909359514713
# precision class 0 = 0.917362630367
# precision class 1 = 0.741421580315
# recall class 0 = 0.986745417118
# recall class 1 = 0.299504935741
# AUC of ROC = 0.895914823124
# AUC of PRC = 0.58981393277
# min(+P, Se) = 0.552475247525
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2725   61]
#  [ 317  119]]
# accuracy = 0.882681548595
# precision class 0 = 0.895792245865
# precision class 1 = 0.661111116409
# recall class 0 = 0.978104829788
# recall class 1 = 0.272935777903
# AUC of ROC = 0.852940982764
# AUC of PRC = 0.544927083331
# min(+P, Se) = 0.510297482838
#
# Epoch 00019: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch19.test0.286496879853.state
# Epoch 20/100
#  - 689s - loss: 0.2421 - val_loss: 0.2867
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15718   201]
#  [ 1402   618]]
# accuracy = 0.910641610622
# precision class 0 = 0.918107450008
# precision class 1 = 0.754578769207
# recall class 0 = 0.987373590469
# recall class 1 = 0.305940598249
# AUC of ROC = 0.898456620428
# AUC of PRC = 0.595192132377
# min(+P, Se) = 0.560891089109
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2723   63]
#  [ 312  124]]
# accuracy = 0.883612692356
# precision class 0 = 0.897199332714
# precision class 1 = 0.663101613522
# recall class 0 = 0.977386951447
# recall class 1 = 0.284403681755
# AUC of ROC = 0.853176432622
# AUC of PRC = 0.539018478211
# min(+P, Se) = 0.516055045872
#
# Epoch 00020: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch20.test0.286748329021.state
# Epoch 21/100
#  - 688s - loss: 0.2406 - val_loss: 0.2891
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15728   191]
#  [ 1411   609]]
# accuracy = 0.910697340965
# precision class 0 = 0.917673170567
# precision class 1 = 0.761250019073
# recall class 0 = 0.988001763821
# recall class 1 = 0.301485151052
# AUC of ROC = 0.900636234551
# AUC of PRC = 0.601464106118
# min(+P, Se) = 0.56407718951
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2735   51]
#  [ 306  130]]
# accuracy = 0.889199256897
# precision class 0 = 0.899375200272
# precision class 1 = 0.718232035637
# recall class 0 = 0.981694161892
# recall class 1 = 0.298165142536
# AUC of ROC = 0.85408736013
# AUC of PRC = 0.544902205172
# min(+P, Se) = 0.514606741573
#
# Epoch 00021: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch21.test0.28910125274.state
# Epoch 22/100
#  - 694s - loss: 0.2395 - val_loss: 0.2919
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15661   258]
#  [ 1341   679]]
# accuracy = 0.910864591599
# precision class 0 = 0.921126902103
# precision class 1 = 0.724653124809
# recall class 0 = 0.983792960644
# recall class 1 = 0.336138606071
# AUC of ROC = 0.898971199494
# AUC of PRC = 0.599441716388
# min(+P, Se) = 0.563861386139
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2713   73]
#  [ 295  141]]
# accuracy = 0.885785222054
# precision class 0 = 0.901928186417
# precision class 1 = 0.65887850523
# recall class 0 = 0.973797559738
# recall class 1 = 0.32339450717
# AUC of ROC = 0.849006665042
# AUC of PRC = 0.540586476557
# min(+P, Se) = 0.507900677201
#
# Epoch 00022: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch22.test0.291855661012.state
# Epoch 23/100
#  - 688s - loss: 0.2382 - val_loss: 0.2872
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15648   271]
#  [ 1304   716]]
# accuracy = 0.912202477455
# precision class 0 = 0.923076927662
# precision class 1 = 0.725430607796
# recall class 0 = 0.982976317406
# recall class 1 = 0.354455441236
# AUC of ROC = 0.902238187259
# AUC of PRC = 0.610916272639
# min(+P, Se) = 0.567501227295
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2710   76]
#  [ 285  151]]
# accuracy = 0.887957811356
# precision class 0 = 0.904841423035
# precision class 1 = 0.665198266506
# recall class 0 = 0.972720742226
# recall class 1 = 0.346330285072
# AUC of ROC = 0.854554966839
# AUC of PRC = 0.549892115628
# min(+P, Se) = 0.517162471396
#
# Epoch 00023: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch23.test0.287159508153.state
# Epoch 24/100
#  - 694s - loss: 0.2382 - val_loss: 0.2880
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15728   191]
#  [ 1387   633]]
# accuracy = 0.912035226822
# precision class 0 = 0.918959975243
# precision class 1 = 0.768203854561
# recall class 0 = 0.988001763821
# recall class 1 = 0.313366323709
# AUC of ROC = 0.901936816271
# AUC of PRC = 0.606690031493
# min(+P, Se) = 0.561881188119
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2727   59]
#  [ 304  132]]
# accuracy = 0.88733702898
# precision class 0 = 0.899703085423
# precision class 1 = 0.691099464893
# recall class 0 = 0.97882270813
# recall class 1 = 0.302752286196
# AUC of ROC = 0.856267741064
# AUC of PRC = 0.547282246504
# min(+P, Se) = 0.520642201835
#
# Epoch 00024: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch24.test0.287975733715.state
# Epoch 25/100
#  - 691s - loss: 0.2386 - val_loss: 0.2864
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15771   148]
#  [ 1431   589]]
# accuracy = 0.911979496479
# precision class 0 = 0.916812002659
# precision class 1 = 0.799185872078
# recall class 0 = 0.990702927113
# recall class 1 = 0.291584163904
# AUC of ROC = 0.902943195098
# AUC of PRC = 0.613240947018
# min(+P, Se) = 0.565841584158
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2743   43]
#  [ 317  119]]
# accuracy = 0.888268172741
# precision class 0 = 0.896405220032
# precision class 1 = 0.73456788063
# recall class 0 = 0.984565675259
# recall class 1 = 0.272935777903
# AUC of ROC = 0.856578106786
# AUC of PRC = 0.554394710775
# min(+P, Se) = 0.516055045872
#
# Epoch 00025: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch25.test0.286423651741.state
# Epoch 26/100
#  - 694s - loss: 0.2392 - val_loss: 0.2862
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15757   162]
#  [ 1421   599]]
# accuracy = 0.911756515503
# precision class 0 = 0.917277932167
# precision class 1 = 0.787122189999
# recall class 0 = 0.989823460579
# recall class 1 = 0.296534657478
# AUC of ROC = 0.903080461793
# AUC of PRC = 0.614189788565
# min(+P, Se) = 0.55950617284
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2736   50]
#  [ 313  123]]
# accuracy = 0.88733702898
# precision class 0 = 0.897343397141
# precision class 1 = 0.710982680321
# recall class 0 = 0.982053101063
# recall class 1 = 0.282110095024
# AUC of ROC = 0.856882709748
# AUC of PRC = 0.550033233663
# min(+P, Se) = 0.51376146789
#
# Epoch 00026: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch26.test0.286226579169.state
# Epoch 27/100
#  - 692s - loss: 0.2356 - val_loss: 0.2847
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15539   380]
#  [ 1179   841]]
# accuracy = 0.91309440136
# precision class 0 = 0.929477214813
# precision class 1 = 0.688779711723
# recall class 0 = 0.976129174232
# recall class 1 = 0.416336625814
# AUC of ROC = 0.905404230824
# AUC of PRC = 0.620849259777
# min(+P, Se) = 0.572277227723
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2683  103]
#  [ 266  170]]
# accuracy = 0.885474860668
# precision class 0 = 0.909799933434
# precision class 1 = 0.622710645199
# recall class 0 = 0.963029444218
# recall class 1 = 0.389908254147
# AUC of ROC = 0.857011136943
# AUC of PRC = 0.551549963559
# min(+P, Se) = 0.512415349887
#
# Epoch 00027: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch27.test0.284681551681.state
# Epoch 28/100
#  - 691s - loss: 0.2369 - val_loss: 0.2860
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15688   231]
#  [ 1321   699]]
# accuracy = 0.913484573364
# precision class 0 = 0.922335207462
# precision class 1 = 0.751612901688
# recall class 0 = 0.985489010811
# recall class 1 = 0.34603959322
# AUC of ROC = 0.904834810386
# AUC of PRC = 0.6154289929
# min(+P, Se) = 0.568811881188
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2711   75]
#  [ 290  146]]
# accuracy = 0.88671630621
# precision class 0 = 0.903365552425
# precision class 1 = 0.660633504391
# recall class 0 = 0.973079681396
# recall class 1 = 0.33486238122
# AUC of ROC = 0.853506556373
# AUC of PRC = 0.544832595849
# min(+P, Se) = 0.509174311927
#
# Epoch 00028: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch28.test0.285991463893.state
# Epoch 29/100
#  - 679s - loss: 0.2330 - val_loss: 0.2882
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15549   370]
#  [ 1189   831]]
# accuracy = 0.91309440136
# precision class 0 = 0.928964018822
# precision class 1 = 0.691923379898
# recall class 0 = 0.976757347584
# recall class 1 = 0.41138613224
# AUC of ROC = 0.905580649936
# AUC of PRC = 0.620363422499
# min(+P, Se) = 0.573267326733
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2685  101]
#  [ 265  171]]
# accuracy = 0.886405944824
# precision class 0 = 0.910169482231
# precision class 1 = 0.628676474094
# recall class 0 = 0.963747322559
# recall class 1 = 0.392201840878
# AUC of ROC = 0.857096755073
# AUC of PRC = 0.55367398337
# min(+P, Se) = 0.518348623853
#
# Epoch 00029: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch29.test0.28823165664.state
# Epoch 30/100
#  - 696s - loss: 0.2343 - val_loss: 0.2841
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15706   213]
#  [ 1353   667]]
# accuracy = 0.91270416975
# precision class 0 = 0.920687019825
# precision class 1 = 0.757954537868
# recall class 0 = 0.986619770527
# recall class 1 = 0.330198019743
# AUC of ROC = 0.906989297303
# AUC of PRC = 0.624641942231
# min(+P, Se) = 0.578217821782
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2718   68]
#  [ 297  139]]
# accuracy = 0.88671630621
# precision class 0 = 0.901492536068
# precision class 1 = 0.671497583389
# recall class 0 = 0.975592255592
# recall class 1 = 0.318807333708
# AUC of ROC = 0.855384392474
# AUC of PRC = 0.549931836002
# min(+P, Se) = 0.510917030568
#
# Epoch 00030: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch30.test0.284141877936.state
# Epoch 31/100
#  - 688s - loss: 0.2321 - val_loss: 0.2881
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15698   221]
#  [ 1328   692]]
# accuracy = 0.913651823997
# precision class 0 = 0.92200165987
# precision class 1 = 0.7579408288
# recall class 0 = 0.986117243767
# recall class 1 = 0.342574268579
# AUC of ROC = 0.907481330299
# AUC of PRC = 0.626183735928
# min(+P, Se) = 0.575952498763
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2718   68]
#  [ 294  142]]
# accuracy = 0.88764744997
# precision class 0 = 0.902390420437
# precision class 1 = 0.676190495491
# recall class 0 = 0.975592255592
# recall class 1 = 0.325688064098
# AUC of ROC = 0.852893234192
# AUC of PRC = 0.54860628277
# min(+P, Se) = 0.506607929515
#
# Epoch 00031: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch31.test0.288099349465.state
# Epoch 32/100
#  - 688s - loss: 0.2359 - val_loss: 0.2847
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15626   293]
#  [ 1231   789]]
# accuracy = 0.915045440197
# precision class 0 = 0.926973938942
# precision class 1 = 0.729205191135
# recall class 0 = 0.981594324112
# recall class 1 = 0.390594065189
# AUC of ROC = 0.907755024042
# AUC of PRC = 0.629588292922
# min(+P, Se) = 0.573762376238
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2700   86]
#  [ 275  161]]
# accuracy = 0.887957811356
# precision class 0 = 0.90756303072
# precision class 1 = 0.65182185173
# recall class 0 = 0.969131350517
# recall class 1 = 0.369266062975
# AUC of ROC = 0.856005123916
# AUC of PRC = 0.550333557359
# min(+P, Se) = 0.519101123596
#
# Epoch 00032: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch32.test0.28465975778.state
# Epoch 33/100
#  - 710s - loss: 0.2333 - val_loss: 0.2885
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15671   248]
#  [ 1280   740]]
# accuracy = 0.914822459221
# precision class 0 = 0.924488246441
# precision class 1 = 0.748987853527
# recall class 0 = 0.984421133995
# recall class 1 = 0.366336643696
# AUC of ROC = 0.90818347712
# AUC of PRC = 0.629337415921
# min(+P, Se) = 0.580613254204
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2706   80]
#  [ 284  152]]
# accuracy = 0.887026667595
# precision class 0 = 0.905016720295
# precision class 1 = 0.655172407627
# recall class 0 = 0.971284985542
# recall class 1 = 0.348623842001
# AUC of ROC = 0.856547646489
# AUC of PRC = 0.550608504191
# min(+P, Se) = 0.516055045872
#
# Epoch 00033: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch33.test0.288488479471.state
# Epoch 34/100
#  - 682s - loss: 0.2341 - val_loss: 0.2879
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15698   221]
#  [ 1311   709]]
# accuracy = 0.914599478245
# precision class 0 = 0.922923147678
# precision class 1 = 0.762365579605
# recall class 0 = 0.986117243767
# recall class 1 = 0.350990086794
# AUC of ROC = 0.90627029535
# AUC of PRC = 0.631406045564
# min(+P, Se) = 0.576942107867
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2712   74]
#  [ 295  141]]
# accuracy = 0.885474860668
# precision class 0 = 0.901895582676
# precision class 1 = 0.655813932419
# recall class 0 = 0.973438620567
# recall class 1 = 0.32339450717
# AUC of ROC = 0.85175220796
# AUC of PRC = 0.543934921418
# min(+P, Se) = 0.506880733945
#
# Epoch 00034: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch34.test0.287947374849.state
# Epoch 35/100
#  - 692s - loss: 0.2323 - val_loss: 0.2843
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15667   252]
#  [ 1293   727]]
# accuracy = 0.913874804974
# precision class 0 = 0.92376178503
# precision class 1 = 0.742594480515
# recall class 0 = 0.984169840813
# recall class 1 = 0.359900981188
# AUC of ROC = 0.907816598137
# AUC of PRC = 0.631233210044
# min(+P, Se) = 0.576732673267
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2710   76]
#  [ 282  154]]
# accuracy = 0.888888895512
# precision class 0 = 0.905748665333
# precision class 1 = 0.669565200806
# recall class 0 = 0.972720742226
# recall class 1 = 0.353211015463
# AUC of ROC = 0.858024559231
# AUC of PRC = 0.554466318263
# min(+P, Se) = 0.509174311927
#
# Epoch 00035: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch35.test0.284294721269.state
# Epoch 36/100
#  - 686s - loss: 0.2320 - val_loss: 0.2810
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15728   191]
#  [ 1337   683]]
# accuracy = 0.914822459221
# precision class 0 = 0.921652495861
# precision class 1 = 0.781464517117
# recall class 0 = 0.988001763821
# recall class 1 = 0.338118821383
# AUC of ROC = 0.910403129954
# AUC of PRC = 0.638751411815
# min(+P, Se) = 0.585148514851
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2723   63]
#  [ 299  137]]
# accuracy = 0.88764744997
# precision class 0 = 0.901058912277
# precision class 1 = 0.685000002384
# recall class 0 = 0.977386951447
# recall class 1 = 0.314220190048
# AUC of ROC = 0.858859335998
# AUC of PRC = 0.554937631096
# min(+P, Se) = 0.524774774775
#
# Epoch 00036: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch36.test0.280963975335.state
# Epoch 37/100
#  - 686s - loss: 0.2336 - val_loss: 0.2865
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15715   204]
#  [ 1327   693]]
# accuracy = 0.914655208588
# precision class 0 = 0.922133564949
# precision class 1 = 0.772575259209
# recall class 0 = 0.987185120583
# recall class 1 = 0.343069314957
# AUC of ROC = 0.909345828106
# AUC of PRC = 0.636131179574
# min(+P, Se) = 0.580198019802
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2721   65]
#  [ 294  142]]
# accuracy = 0.888578534126
# precision class 0 = 0.902487576008
# precision class 1 = 0.685990333557
# recall class 0 = 0.976669073105
# recall class 1 = 0.325688064098
# AUC of ROC = 0.855881636228
# AUC of PRC = 0.548696291787
# min(+P, Se) = 0.516853932584
#
# Epoch 00037: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch37.test0.286455367762.state
# Epoch 38/100
#  - 687s - loss: 0.2324 - val_loss: 0.2880
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15797   122]
#  [ 1447   573]]
# accuracy = 0.912536919117
# precision class 0 = 0.916086733341
# precision class 1 = 0.824460446835
# recall class 0 = 0.992336213589
# recall class 1 = 0.283663362265
# AUC of ROC = 0.909397699617
# AUC of PRC = 0.634857828126
# min(+P, Se) = 0.580198019802
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2745   41]
#  [ 319  117]]
# accuracy = 0.888268172741
# precision class 0 = 0.895887732506
# precision class 1 = 0.740506350994
# recall class 0 = 0.9852835536
# recall class 1 = 0.268348634243
# AUC of ROC = 0.854932427537
# AUC of PRC = 0.553947133539
# min(+P, Se) = 0.534403669725
#
# Epoch 00038: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch38.test0.287958913051.state
# Epoch 39/100
#  - 699s - loss: 0.2315 - val_loss: 0.2906
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15744   175]
#  [ 1372   648]]
# accuracy = 0.913763284683
# precision class 0 = 0.919841110706
# precision class 1 = 0.787363290787
# recall class 0 = 0.989006876945
# recall class 1 = 0.320792078972
# AUC of ROC = 0.910230504802
# AUC of PRC = 0.636717709837
# min(+P, Se) = 0.586138613861
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2725   61]
#  [ 302  134]]
# accuracy = 0.88733702898
# precision class 0 = 0.90023124218
# precision class 1 = 0.687179505825
# recall class 0 = 0.978104829788
# recall class 1 = 0.307339459658
# AUC of ROC = 0.850700916114
# AUC of PRC = 0.544099158234
# min(+P, Se) = 0.518348623853
#
# Epoch 00039: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch39.test0.290554025375.state
# Epoch 40/100
#  - 695s - loss: 0.2330 - val_loss: 0.2849
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15639   280]
#  [ 1229   791]]
# accuracy = 0.915881574154
# precision class 0 = 0.927140176296
# precision class 1 = 0.738562107086
# recall class 0 = 0.98241096735
# recall class 1 = 0.391584157944
# AUC of ROC = 0.910126077624
# AUC of PRC = 0.635029993704
# min(+P, Se) = 0.575742574257
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2697   89]
#  [ 280  156]]
# accuracy = 0.885474860668
# precision class 0 = 0.905945599079
# precision class 1 = 0.63673466444
# recall class 0 = 0.968054533005
# recall class 1 = 0.357798159122
# AUC of ROC = 0.855570447256
# AUC of PRC = 0.548280604257
# min(+P, Se) = 0.51376146789
#
# Epoch 00040: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch40.test0.284900377222.state
# Epoch 41/100
#  - 688s - loss: 0.2319 - val_loss: 0.2847
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15747   172]
#  [ 1360   660]]
# accuracy = 0.914599478245
# precision class 0 = 0.920500397682
# precision class 1 = 0.793269217014
# recall class 0 = 0.989195287228
# recall class 1 = 0.3267326653
# AUC of ROC = 0.909394947441
# AUC of PRC = 0.639271368293
# min(+P, Se) = 0.581683168317
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2731   55]
#  [ 301  135]]
# accuracy = 0.889509618282
# precision class 0 = 0.900725603104
# precision class 1 = 0.710526287556
# recall class 0 = 0.980258464813
# recall class 1 = 0.309633016586
# AUC of ROC = 0.853924768008
# AUC of PRC = 0.553630675007
# min(+P, Se) = 0.520642201835
#
# Epoch 00041: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch41.test0.284734215821.state
# Epoch 42/100
#  - 678s - loss: 0.2325 - val_loss: 0.2886
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15542   377]
#  [ 1108   912]]
# accuracy = 0.917219460011
# precision class 0 = 0.933453440666
# precision class 1 = 0.707525193691
# recall class 0 = 0.976317584515
# recall class 1 = 0.451485157013
# AUC of ROC = 0.909839602592
# AUC of PRC = 0.641082680873
# min(+P, Se) = 0.581188118812
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2684  102]
#  [ 265  171]]
# accuracy = 0.886095583439
# precision class 0 = 0.910139024258
# precision class 1 = 0.626373648643
# recall class 0 = 0.963388383389
# recall class 1 = 0.392201840878
# AUC of ROC = 0.856973267385
# AUC of PRC = 0.555480928877
# min(+P, Se) = 0.529545454545
#
# Epoch 00042: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch42.test0.288577002932.state
# Epoch 43/100
#  - 681s - loss: 0.2324 - val_loss: 0.2890
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15748   171]
#  [ 1346   674]]
# accuracy = 0.915435671806
# precision class 0 = 0.921258926392
# precision class 1 = 0.797633111477
# recall class 0 = 0.989258110523
# recall class 1 = 0.333663374186
# AUC of ROC = 0.908946078508
# AUC of PRC = 0.640475986021
# min(+P, Se) = 0.579702970297
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2725   61]
#  [ 299  137]]
# accuracy = 0.888268172741
# precision class 0 = 0.901124358177
# precision class 1 = 0.691919207573
# recall class 0 = 0.978104829788
# recall class 1 = 0.314220190048
# AUC of ROC = 0.85525020252
# AUC of PRC = 0.554145763772
# min(+P, Se) = 0.518348623853
#
# Epoch 00043: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch43.test0.28904680106.state
# Epoch 44/100
#  - 696s - loss: 0.2314 - val_loss: 0.2944
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15754   165]
#  [ 1379   641]]
# accuracy = 0.913930535316
# precision class 0 = 0.919512033463
# precision class 1 = 0.795285344124
# recall class 0 = 0.989635050297
# recall class 1 = 0.317326724529
# AUC of ROC = 0.910482025651
# AUC of PRC = 0.640819377575
# min(+P, Se) = 0.585148514851
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2733   53]
#  [ 313  123]]
# accuracy = 0.886405944824
# precision class 0 = 0.897242307663
# precision class 1 = 0.698863625526
# recall class 0 = 0.98097628355
# recall class 1 = 0.282110095024
# AUC of ROC = 0.85469039167
# AUC of PRC = 0.562235360994
# min(+P, Se) = 0.516055045872
#
# Epoch 00044: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch44.test0.294408535593.state
# Epoch 45/100
#  - 697s - loss: 0.2313 - val_loss: 0.2854
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15752   167]
#  [ 1329   691]]
# accuracy = 0.916606247425
# precision class 0 = 0.922194242477
# precision class 1 = 0.805361330509
# recall class 0 = 0.989509403706
# recall class 1 = 0.342079222202
# AUC of ROC = 0.912192619318
# AUC of PRC = 0.651060254143
# min(+P, Se) = 0.596941292551
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2727   59]
#  [ 306  130]]
# accuracy = 0.88671630621
# precision class 0 = 0.899109780788
# precision class 1 = 0.687830686569
# recall class 0 = 0.97882270813
# recall class 1 = 0.298165142536
# AUC of ROC = 0.854748842509
# AUC of PRC = 0.557051690104
# min(+P, Se) = 0.526315789474
#
# Epoch 00045: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch45.test0.285423516279.state
# Epoch 46/100
#  - 686s - loss: 0.2315 - val_loss: 0.2831
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15677   242]
#  [ 1255   765]]
# accuracy = 0.916550517082
# precision class 0 = 0.925880014896
# precision class 1 = 0.759682238102
# recall class 0 = 0.984798014164
# recall class 1 = 0.37871286273
# AUC of ROC = 0.91185136511
# AUC of PRC = 0.645280569437
# min(+P, Se) = 0.588613861386
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2711   75]
#  [ 287  149]]
# accuracy = 0.88764744997
# precision class 0 = 0.904269516468
# precision class 1 = 0.665178596973
# recall class 0 = 0.973079681396
# recall class 1 = 0.34174311161
# AUC of ROC = 0.858808294421
# AUC of PRC = 0.555448605209
# min(+P, Se) = 0.536697247706
#
# Epoch 00046: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch46.test0.283087510664.state
# Epoch 47/100
#  - 689s - loss: 0.2302 - val_loss: 0.2822
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15665   254]
#  [ 1217   803]]
# accuracy = 0.917999863625
# precision class 0 = 0.927911400795
# precision class 1 = 0.759697258472
# recall class 0 = 0.984044194221
# recall class 1 = 0.397524744272
# AUC of ROC = 0.912871318227
# AUC of PRC = 0.653200064917
# min(+P, Se) = 0.589807026225
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2705   81]
#  [ 279  157]]
# accuracy = 0.888268172741
# precision class 0 = 0.906501352787
# precision class 1 = 0.65966385603
# recall class 0 = 0.970926046371
# recall class 1 = 0.360091745853
# AUC of ROC = 0.858153809677
# AUC of PRC = 0.556222505941
# min(+P, Se) = 0.519450800915
#
# Epoch 00047: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch47.test0.282212249398.state
# Epoch 48/100
#  - 679s - loss: 0.2313 - val_loss: 0.2874
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15660   259]
#  [ 1222   798]]
# accuracy = 0.917442440987
# precision class 0 = 0.927615225315
# precision class 1 = 0.754966914654
# recall class 0 = 0.983730137348
# recall class 1 = 0.395049512386
# AUC of ROC = 0.913151091634
# AUC of PRC = 0.650697300426
# min(+P, Se) = 0.59702970297
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2702   84]
#  [ 279  157]]
# accuracy = 0.88733702898
# precision class 0 = 0.906407237053
# precision class 1 = 0.651452302933
# recall class 0 = 0.969849228859
# recall class 1 = 0.360091745853
# AUC of ROC = 0.855768027556
# AUC of PRC = 0.554038937346
# min(+P, Se) = 0.520642201835
#
# Epoch 00048: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch48.test0.287448057224.state
# Epoch 49/100
#  - 699s - loss: 0.2296 - val_loss: 0.2819
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15654   265]
#  [ 1219   801]]
# accuracy = 0.917275190353
# precision class 0 = 0.927754402161
# precision class 1 = 0.751407146454
# recall class 0 = 0.983353197575
# recall class 1 = 0.396534651518
# AUC of ROC = 0.914746047285
# AUC of PRC = 0.65425621673
# min(+P, Se) = 0.59900990099
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2701   85]
#  [ 279  157]]
# accuracy = 0.887026667595
# precision class 0 = 0.906375825405
# precision class 1 = 0.648760318756
# recall class 0 = 0.969490289688
# recall class 1 = 0.360091745853
# AUC of ROC = 0.857348669955
# AUC of PRC = 0.555645515797
# min(+P, Se) = 0.529816513761
#
# Epoch 00049: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch49.test0.281857921512.state
# Epoch 50/100
#  - 690s - loss: 0.2298 - val_loss: 0.2845
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15710   209]
#  [ 1283   737]]
# accuracy = 0.916829228401
# precision class 0 = 0.924498319626
# precision class 1 = 0.779069781303
# recall class 0 = 0.986871063709
# recall class 1 = 0.364851474762
# AUC of ROC = 0.914257419523
# AUC of PRC = 0.651366975751
# min(+P, Se) = 0.591089108911
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2718   68]
#  [ 293  143]]
# accuracy = 0.887957811356
# precision class 0 = 0.902690112591
# precision class 1 = 0.67772513628
# recall class 0 = 0.975592255592
# recall class 1 = 0.327981650829
# AUC of ROC = 0.858416426826
# AUC of PRC = 0.555693704904
# min(+P, Se) = 0.52752293578
#
# Epoch 00050: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch50.test0.284534339581.state
# Epoch 51/100
#  - 689s - loss: 0.2298 - val_loss: 0.2836
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15665   254]
#  [ 1219   801]]
# accuracy = 0.917888402939
# precision class 0 = 0.92780148983
# precision class 1 = 0.759241700172
# recall class 0 = 0.984044194221
# recall class 1 = 0.396534651518
# AUC of ROC = 0.914635524894
# AUC of PRC = 0.65143595987
# min(+P, Se) = 0.589452932479
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2701   85]
#  [ 277  159]]
# accuracy = 0.88764744997
# precision class 0 = 0.906984567642
# precision class 1 = 0.651639342308
# recall class 0 = 0.969490289688
# recall class 1 = 0.364678889513
# AUC of ROC = 0.859370575025
# AUC of PRC = 0.554042335236
# min(+P, Se) = 0.529816513761
#
# Epoch 00051: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch51.test0.283580914052.state
# Epoch 52/100
#  - 697s - loss: 0.2280 - val_loss: 0.2884
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15740   179]
#  [ 1292   728]]
# accuracy = 0.917999863625
# precision class 0 = 0.92414277792
# precision class 1 = 0.802646100521
# recall class 0 = 0.988755583763
# recall class 1 = 0.360396027565
# AUC of ROC = 0.915258091862
# AUC of PRC = 0.66049663476
# min(+P, Se) = 0.596534653465
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2716   70]
#  [ 294  142]]
# accuracy = 0.887026667595
# precision class 0 = 0.902325570583
# precision class 1 = 0.669811308384
# recall class 0 = 0.974874377251
# recall class 1 = 0.325688064098
# AUC of ROC = 0.85522385848
# AUC of PRC = 0.552737140357
# min(+P, Se) = 0.52752293578
#
# Epoch 00052: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch52.test0.288386003182.state
# Epoch 53/100
#  - 686s - loss: 0.2303 - val_loss: 0.2909
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15758   161]
#  [ 1340   680]]
# accuracy = 0.916327536106
# ...
# precision class 0 = 0.903935968876
# precision class 1 = 0.660714268684
# recall class 0 = 0.972720742226
# recall class 1 = 0.339449554682
# AUC of ROC = 0.849118627212
# AUC of PRC = 0.546872632845
# min(+P, Se) = 0.510297482838
#
# Epoch 00081: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch81.test0.289580981584.state
# Epoch 82/100
#  - 699s - loss: 0.2249 - val_loss: 0.2877
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15691   228]
#  [ 1183   837]]
# accuracy = 0.921344578266
# precision class 0 = 0.929892122746
# precision class 1 = 0.785915493965
# recall class 0 = 0.985677480698
# recall class 1 = 0.414356440306
# AUC of ROC = 0.923475263696
# AUC of PRC = 0.682561825417
# min(+P, Se) = 0.616600790514
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2696   90]
#  [ 285  151]]
# accuracy = 0.883612692356
# precision class 0 = 0.904394507408
# precision class 1 = 0.626556038857
# recall class 0 = 0.967695593834
# recall class 1 = 0.346330285072
# AUC of ROC = 0.854170920131
# AUC of PRC = 0.553761821458
# min(+P, Se) = 0.51598173516
#
# Epoch 00082: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch82.test0.287666409126.state
# Epoch 83/100
#  - 700s - loss: 0.2220 - val_loss: 0.2936
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15746   173]
#  [ 1240   780]]
# accuracy = 0.921233057976
# precision class 0 = 0.926998734474
# precision class 1 = 0.818467974663
# recall class 0 = 0.989132463932
# recall class 1 = 0.386138617992
# AUC of ROC = 0.922002663235
# AUC of PRC = 0.681405299435
# min(+P, Se) = 0.617472852912
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2719   67]
#  [ 298  138]]
# accuracy = 0.88671630621
# precision class 0 = 0.901226401329
# precision class 1 = 0.673170745373
# recall class 0 = 0.975951194763
# recall class 1 = 0.316513746977
# AUC of ROC = 0.849677614811
# AUC of PRC = 0.5497532908
# min(+P, Se) = 0.511467889908
#
# Epoch 00083: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch83.test0.293568465769.state
# Epoch 84/100
#  - 696s - loss: 0.2235 - val_loss: 0.2913
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15698   221]
#  [ 1201   819]]
# accuracy = 0.920731365681
# precision class 0 = 0.928930699825
# precision class 1 = 0.787500023842
# recall class 0 = 0.986117243767
# recall class 1 = 0.405445545912
# AUC of ROC = 0.922429856843
# AUC of PRC = 0.682724895777
# min(+P, Se) = 0.612871287129
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2707   79]
#  [ 285  151]]
# accuracy = 0.887026667595
# precision class 0 = 0.904745995998
# precision class 1 = 0.656521737576
# recall class 0 = 0.971643924713
# recall class 1 = 0.346330285072
# AUC of ROC = 0.850010208315
# AUC of PRC = 0.553825530976
# min(+P, Se) = 0.522935779817
#
# Epoch 00084: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch84.test0.291261031528.state
# Epoch 85/100
#  - 683s - loss: 0.2236 - val_loss: 0.2884
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15630   289]
#  [ 1109   911]]
# accuracy = 0.922069251537
# precision class 0 = 0.933747529984
# precision class 1 = 0.759166657925
# recall class 0 = 0.981845617294
# recall class 1 = 0.450990110636
# AUC of ROC = 0.923845812246
# AUC of PRC = 0.683802570174
# min(+P, Se) = 0.615727002967
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2682  104]
#  [ 267  169]]
# accuracy = 0.884854137897
# precision class 0 = 0.909460842609
# precision class 1 = 0.619047641754
# recall class 0 = 0.962670505047
# recall class 1 = 0.387614667416
# AUC of ROC = 0.856711473488
# AUC of PRC = 0.556217989264
# min(+P, Se) = 0.510297482838
#
# Epoch 00085: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch85.test0.28840325718.state
# Epoch 86/100
#  - 699s - loss: 0.2230 - val_loss: 0.2822
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15774   145]
#  [ 1293   727]]
# accuracy = 0.919839441776
# precision class 0 = 0.924239754677
# precision class 1 = 0.833715617657
# recall class 0 = 0.990891396999
# recall class 1 = 0.359900981188
# AUC of ROC = 0.924799371073
# AUC of PRC = 0.690421426562
# min(+P, Se) = 0.621287128713
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2729   57]
#  [ 296  140]]
# accuracy = 0.890440702438
# precision class 0 = 0.902148783207
# precision class 1 = 0.710659921169
# recall class 0 = 0.979540586472
# recall class 1 = 0.321100920439
# AUC of ROC = 0.855266667545
# AUC of PRC = 0.566572191602
# min(+P, Se) = 0.524027459954
#
# Epoch 00086: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch86.test0.282167907437.state
# Epoch 87/100
#  - 699s - loss: 0.2245 - val_loss: 0.2863
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15756   163]
#  [ 1241   779]]
# accuracy = 0.921734750271
# precision class 0 = 0.926987111568
# precision class 1 = 0.82696390152
# recall class 0 = 0.989760637283
# recall class 1 = 0.385643571615
# AUC of ROC = 0.923314689029
# AUC of PRC = 0.688942025636
# min(+P, Se) = 0.625432953983
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2719   67]
#  [ 293  143]]
# accuracy = 0.888268172741
# precision class 0 = 0.902722418308
# precision class 1 = 0.680952370167
# recall class 0 = 0.975951194763
# recall class 1 = 0.327981650829
# AUC of ROC = 0.853872903179
# AUC of PRC = 0.562789424189
# min(+P, Se) = 0.525229357798
#
# Epoch 00087: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch87.test0.286296267143.state
# Epoch 88/100
#  - 687s - loss: 0.2232 - val_loss: 0.2866
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15616   303]
#  [ 1079   941]]
# accuracy = 0.922961175442
# precision class 0 = 0.935369849205
# precision class 1 = 0.756430864334
# recall class 0 = 0.980966150761
# recall class 1 = 0.465841591358
# AUC of ROC = 0.922088773674
# AUC of PRC = 0.687504392912
# min(+P, Se) = 0.620484908461
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2678  108]
#  [ 261  175]]
# accuracy = 0.885474860668
# precision class 0 = 0.911194264889
# precision class 1 = 0.618374586105
# recall class 0 = 0.961234748363
# recall class 1 = 0.401376157999
# AUC of ROC = 0.852729407193
# AUC of PRC = 0.556737180308
# min(+P, Se) = 0.516055045872
#
# Epoch 00088: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch88.test0.286643651666.state
# Epoch 89/100
#  - 687s - loss: 0.2206 - val_loss: 0.2869
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15695   224]
#  [ 1177   843]]
# accuracy = 0.921902000904
# precision class 0 = 0.930239439011
# precision class 1 = 0.790065586567
# recall class 0 = 0.98592877388
# recall class 1 = 0.417326718569
# AUC of ROC = 0.924960334466
# AUC of PRC = 0.692372240607
# min(+P, Se) = 0.627596439169
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2710   76]
#  [ 274  162]]
# accuracy = 0.891371846199
# precision class 0 = 0.908176958561
# precision class 1 = 0.680672287941
# recall class 0 = 0.972720742226
# recall class 1 = 0.371559619904
# AUC of ROC = 0.853486386717
# AUC of PRC = 0.563645343045
# min(+P, Se) = 0.525229357798
#
# Epoch 00089: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch89.test0.286881231949.state
# Epoch 90/100
#  - 689s - loss: 0.2230 - val_loss: 0.2902
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15738   181]
#  [ 1203   817]]
# accuracy = 0.922849655151
# precision class 0 = 0.928988814354
# precision class 1 = 0.818637251854
# recall class 0 = 0.988629937172
# recall class 1 = 0.404455453157
# AUC of ROC = 0.923905022891
# AUC of PRC = 0.69342854146
# min(+P, Se) = 0.620297029703
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2716   70]
#  [ 282  154]]
# accuracy = 0.890751063824
# precision class 0 = 0.905937314034
# precision class 1 = 0.6875
# recall class 0 = 0.974874377251
# recall class 1 = 0.353211015463
# AUC of ROC = 0.854452472059
# AUC of PRC = 0.567548191917
# min(+P, Se) = 0.511467889908
#
# Epoch 00090: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch90.test0.290192863251.state
# Epoch 91/100
#  - 694s - loss: 0.2233 - val_loss: 0.2933
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15667   252]
#  [ 1150   870]]
# accuracy = 0.921846270561
# precision class 0 = 0.931616842747
# precision class 1 = 0.775401055813
# recall class 0 = 0.984169840813
# recall class 1 = 0.43069306016
# AUC of ROC = 0.922022177248
# AUC of PRC = 0.684043507397
# min(+P, Se) = 0.611468116658
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2691   95]
#  [ 280  156]]
# accuracy = 0.883612692356
# precision class 0 = 0.905755639076
# precision class 1 = 0.621513962746
# recall class 0 = 0.965900957584
# recall class 1 = 0.357798159122
# AUC of ROC = 0.848614797447
# AUC of PRC = 0.553163353968
# min(+P, Se) = 0.505592841163
#
# Epoch 00091: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch91.test0.293303092663.state
# Epoch 92/100
#  - 696s - loss: 0.2262 - val_loss: 0.2913
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15765   154]
#  [ 1264   756]]
# accuracy = 0.920954346657
# precision class 0 = 0.92577368021
# precision class 1 = 0.830769240856
# recall class 0 = 0.990326046944
# recall class 1 = 0.374257415533
# AUC of ROC = 0.922874854073
# AUC of PRC = 0.689915507261
# min(+P, Se) = 0.616336633663
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2723   63]
#  [ 299  137]]
# accuracy = 0.88764744997
# precision class 0 = 0.901058912277
# precision class 1 = 0.685000002384
# recall class 0 = 0.977386951447
# recall class 1 = 0.314220190048
# AUC of ROC = 0.847367571804
# AUC of PRC = 0.553405725748
# min(+P, Se) = 0.50566893424
#
# Epoch 00092: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch92.test0.291290348131.state
# Epoch 93/100
#  - 689s - loss: 0.2220 - val_loss: 0.2920
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15698   221]
#  [ 1172   848]]
# accuracy = 0.922347962856
# precision class 0 = 0.930527567863
# precision class 1 = 0.793264746666
# recall class 0 = 0.986117243767
# recall class 1 = 0.419801980257
# AUC of ROC = 0.924549249636
# AUC of PRC = 0.691927966341
# min(+P, Se) = 0.620792079208
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2702   84]
#  [ 273  163]]
# accuracy = 0.889199256897
# precision class 0 = 0.908235311508
# precision class 1 = 0.659919023514
# recall class 0 = 0.969849228859
# recall class 1 = 0.373853206635
# AUC of ROC = 0.850829343309
# AUC of PRC = 0.556018426776
# min(+P, Se) = 0.506880733945
#
# Epoch 00093: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch93.test0.291991960826.state
# Epoch 94/100
#  - 697s - loss: 0.2226 - val_loss: 0.2925
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15804   115]
#  [ 1301   719]]
# accuracy = 0.921065807343
# precision class 0 = 0.923940360546
# precision class 1 = 0.862110316753
# recall class 0 = 0.992775917053
# recall class 1 = 0.355940580368
# AUC of ROC = 0.924377013209
# AUC of PRC = 0.691762839276
# min(+P, Se) = 0.622277227723
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2734   52]
#  [ 312  124]]
# accuracy = 0.887026667595
# precision class 0 = 0.897570610046
# precision class 1 = 0.70454543829
# recall class 0 = 0.981335222721
# recall class 1 = 0.284403681755
# AUC of ROC = 0.851552981157
# AUC of PRC = 0.550699329338
# min(+P, Se) = 0.508009153318
#
# Epoch 00094: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch94.test0.292546486569.state
# Epoch 95/100
#  - 680s - loss: 0.2265 - val_loss: 0.2910
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15741   178]
#  [ 1224   796]]
# accuracy = 0.921846270561
# precision class 0 = 0.927851438522
# precision class 1 = 0.817248463631
# recall class 0 = 0.988818407059
# recall class 1 = 0.394059419632
# AUC of ROC = 0.923883223174
# AUC of PRC = 0.692282878812
# min(+P, Se) = 0.620297029703
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2723   63]
#  [ 285  151]]
# accuracy = 0.89199256897
# precision class 0 = 0.905252635479
# precision class 1 = 0.70560747385
# recall class 0 = 0.977386951447
# recall class 1 = 0.346330285072
# AUC of ROC = 0.850419364187
# AUC of PRC = 0.557004079134
# min(+P, Se) = 0.510297482838
#
# Epoch 00095: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch95.test0.290994048966.state
# Epoch 96/100
#  - 699s - loss: 0.2202 - val_loss: 0.2950
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15787   132]
#  [ 1281   739]]
# accuracy = 0.921233057976
# precision class 0 = 0.92494726181
# precision class 1 = 0.848450064659
# recall class 0 = 0.991708040237
# recall class 1 = 0.365841597319
# AUC of ROC = 0.924901839075
# AUC of PRC = 0.698019975076
# min(+P, Se) = 0.624752475248
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2737   49]
#  [ 305  131]]
# accuracy = 0.890130341053
# precision class 0 = 0.899737000465
# precision class 1 = 0.727777779102
# recall class 0 = 0.982412040234
# recall class 1 = 0.300458729267
# AUC of ROC = 0.844890408794
# AUC of PRC = 0.547981487411
# min(+P, Se) = 0.504484304933
#
# Epoch 00096: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch96.test0.295036378774.state
# Epoch 97/100
#  - 700s - loss: 0.2249 - val_loss: 0.2892
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15760   159]
#  [ 1246   774]]
# accuracy = 0.921679019928
# precision class 0 = 0.92673176527
# precision class 1 = 0.829581975937
# recall class 0 = 0.990011930466
# recall class 1 = 0.383168309927
# AUC of ROC = 0.924368803329
# AUC of PRC = 0.69267902192
# min(+P, Se) = 0.617588932806
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2726   60]
#  [ 293  143]]
# accuracy = 0.890440702438
# precision class 0 = 0.902948021889
# precision class 1 = 0.704433500767
# recall class 0 = 0.978463768959
# recall class 1 = 0.327981650829
# AUC of ROC = 0.852855364634
# AUC of PRC = 0.564523549497
# min(+P, Se) = 0.510250569476
#
# Epoch 00097: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch97.test0.289163900528.state
# Epoch 98/100
#  - 696s - loss: 0.2237 - val_loss: 0.2831
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15699   220]
#  [ 1147   873]]
# accuracy = 0.923797309399
# precision class 0 = 0.931912600994
# precision class 1 = 0.798719108105
# recall class 0 = 0.986180007458
# recall class 1 = 0.432178229094
# AUC of ROC = 0.924740549154
# AUC of PRC = 0.698025709534
# min(+P, Se) = 0.627227722772
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2703   83]
#  [ 272  164]]
# accuracy = 0.889819979668
# precision class 0 = 0.9085714221
# precision class 1 = 0.663967609406
# recall class 0 = 0.97020816803
# recall class 1 = 0.376146793365
# AUC of ROC = 0.855532577698
# AUC of PRC = 0.567636303059
# min(+P, Se) = 0.518348623853
#
# Epoch 00098: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch98.test0.283087574107.state
# Epoch 99/100
#  - 693s - loss: 0.2233 - val_loss: 0.2865
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15767   152]
#  [ 1251   769]]
# accuracy = 0.921790540218
# precision class 0 = 0.926489591599
# precision class 1 = 0.834962010384
# recall class 0 = 0.99045163393
# recall class 1 = 0.380693078041
# AUC of ROC = 0.926267959889
# AUC of PRC = 0.698241333154
# min(+P, Se) = 0.620860108749
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2732   54]
#  [ 298  138]]
# accuracy = 0.890751063824
# precision class 0 = 0.901650190353
# precision class 1 = 0.71875
# recall class 0 = 0.980617344379
# recall class 1 = 0.316513746977
# AUC of ROC = 0.85344563578
# AUC of PRC = 0.556273600143
# min(+P, Se) = 0.506880733945
#
# Epoch 00099: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch99.test0.28652081384.state
# Epoch 100/100
#  - 696s - loss: 0.2219 - val_loss: 0.2917
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15678   241]
#  [ 1116   904]]
# accuracy = 0.924354732037
# precision class 0 = 0.93354767561
# precision class 1 = 0.789519667625
# recall class 0 = 0.98486083746
# recall class 1 = 0.447524756193
# AUC of ROC = 0.926537641986
# AUC of PRC = 0.700440157375
# min(+P, Se) = 0.622277227723
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[2698   88]
#  [ 272  164]]
# accuracy = 0.888268172741
# precision class 0 = 0.908417522907
# precision class 1 = 0.650793671608
# recall class 0 = 0.968413472176
# recall class 1 = 0.376146793365
# AUC of ROC = 0.847887043343
# AUC of PRC = 0.550956093368
# min(+P, Se) = 0.504587155963
#
# Epoch 00100: saving model to in_hospital_mortality/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.epoch100.test0.291660803286.state
