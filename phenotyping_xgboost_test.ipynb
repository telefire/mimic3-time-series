# %%
! python phenotyping/xgboost/main.py  --output_dir phenotyping/xgboost/
# Out:
# Namespace(data='phenotyping/xgboost/../../../data/phenotyping/', features='all', output_dir='phenotyping/xgboost/', period='all')
# Reading data and extracting features ...
# number of get_number_of_examples 36020
# number of get_number_of_examples 6371
# number of get_number_of_examples 6281
#   train data shape = (36020, 714)
#   validation data shape = (6371, 714)
#   test data shape = (6281, 714)
# Imputing missing values ...
# /home/yanke/anaconda2/envs/py37/lib/python3.7/site-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# Normalizing the data to have zero mean and unit variance ...
# Starting task 0
# ...
