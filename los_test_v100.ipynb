# %%
! python length_of_stay/main.py --network models/lstm.py --dim 16 --timestep 1.0 --depth 2 --dropout 0.3 --mode test --batch_size 8 --load_state length_of_stay/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.partition=custom.chunk59.test1.84807832915.state
# Out:
# Using TensorFlow backend.
# 2019-07-23 19:32:53.615803: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='length_of_stay/../../data/length-of-stay/', deep_supervision=False, depth=2, dim=16, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='length_of_stay/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.partition=custom.chunk59.test1.84807832915.state', lr=0.001, mode='test', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='.', partition='custom', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ...

# %%
! python length_of_stay/main.py --network models/lstm.py --dim 16 --timestep 1.0 --depth 2 --dropout 0.3 --mode test --batch_size 8 --load_state length_of_stay/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.partition=custom.chunk59.test1.84807832915.state
# Out:
# Using TensorFlow backend.
# 2019-07-24 01:15:32.133226: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='length_of_stay/../../data/length-of-stay/', deep_supervision=False, depth=2, dim=16, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='length_of_stay/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.partition=custom.chunk59.test1.84807832915.state', lr=0.001, mode='test', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='.', partition='custom', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ...
