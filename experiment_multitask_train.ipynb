# %%
! python3 multitask/main.py --network models/multitask_lstm.py --dim 512  --timestep 1.0  --dropout 0.3 --mode train --batch_size 16  --ihm_C 0.2 --decomp_C 1.0 --los_C 1.5 --pheno_C 1.0   --output_dir multitask/
# Out:
# Using TensorFlow backend.
# Namespace(batch_norm=False, batch_size=16, beta_1=0.9, data='multitask/../../data/multitask/', decomp_C=1.0, depth=1, dim=512, dropout=0.3, epochs=100, ihm_C=0.2, imputation='previous', l1=0, l2=0, load_state='', los_C=1.5, lr=0.001, mode='train', network='models/multitask_lstm.py', normalizer_state=None, optimizer='adam', output_dir='multitask/', partition='custom', pheno_C=1.0, prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, target_repl_coef=0.0, timestep=1.0, verbose=2)
# ==> using model models/multitask_lstm.py
# ==> not used params in network class: dict_keys(['mode', 'prefix', 'verbose', 'l1', 'header', 'target_repl_coef', 'batch_size', 'data', 'beta_1', 'l2', 'load_state', 'imputation', 'size_coef', 'los_C', 'network', 'decomp_C', 'normalizer_state', 'pheno_C', 'save_every', 'timestep', 'ihm_C', 'optimizer', 'lr', 'small_part', 'output_dir', 'epochs'])
# ...
