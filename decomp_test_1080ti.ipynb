# %%
! python decompensation/main.py --network models/lstm.py --dim 16 --timestep 1.0 --depth 2 --dropout 0.3 --mode test --batch_size 8 --load_state decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk7.test0.0843504593479.state
# Out:
# decompensation/main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Using TensorFlow backend.
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='decompensation/../../data/decompensation/', deep_supervision=False, depth=2, dim=16, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk7.test0.0843504593479.state', lr=0.001, mode='test', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='.', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ...

# %%
! python decompensation/main.py --network models/lstm.py --dim 16 --timestep 1.0 --depth 2 --dropout 0.3 --mode test --batch_size 8 --load_state decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk17.test0.0783771921347.state
# Out:
# decompensation/main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Using TensorFlow backend.
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='decompensation/../../data/decompensation/', deep_supervision=False, depth=2, dim=16, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk17.test0.0783771921347.state', lr=0.001, mode='test', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='.', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ...
