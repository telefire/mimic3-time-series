# %%
! python decompensation/main.py --network models/lstm.py --dim 16 --timestep 1.0 --depth 2 --dropout 0.3 --mode train --batch_size 8 --output_dir decompensation
# Out:
# Using TensorFlow backend.
# 2019-06-22 22:17:04.757486: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# Namespace(batch_norm=False, batch_size=8, beta_1=0.9, data='decompensation/../../data/decompensation/', deep_supervision=False, depth=2, dim=16, dropout=0.3, epochs=100, imputation='previous', l1=0, l2=0, load_state='', lr=0.001, mode='train', network='models/lstm.py', normalizer_state=None, optimizer='adam', output_dir='decompensation', prefix='', rec_dropout=0.0, save_every=1, size_coef=4.0, small_part=False, timestep=1.0, verbose=2)
# ==> using model models/lstm.py
# ==> not used params in network class: ['beta_1', 'size_coef', 'verbose', 'small_part', 'timestep', 'imputation', 'l2', 'batch_size', 'data', 'epochs', 'header', 'prefix', 'load_state', 'output_dir', 'l1', 'lr', 'mode', 'normalizer_state', 'optimizer', 'save_every', 'network']
# WARNING: Logging before flag parsing goes to stderr.
# W0622 22:17:21.668638 140289196012992 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0622 22:17:21.700898 140289196012992 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0622 22:17:21.709338 140289196012992 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0622 22:17:21.812154 140289196012992 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0622 22:17:21.817723 140289196012992 deprecation.py:506] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0622 22:17:21.958280 140289196012992 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:2974: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ==> model.final_name: k_lstm.n16.d0.3.dep2.bs8.ts1.0
# ==> compiling the model
# W0622 22:17:22.409768 140289196012992 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0622 22:17:22.424583 140289196012992 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# X (InputLayer)               (None, None, 76)          0
# _________________________________________________________________
# masking_1 (Masking)          (None, None, 76)          0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, None, 16)          5440
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 7,569
# Trainable params: 7,569
# Non-trainable params: 0
# _________________________________________________________________
# ==> training
# Epoch 1/100
# 2019-06-22 22:24:13.099586: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-22 22:24:13.117453: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-06-22 22:24:14.172309: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-22 22:24:14.174459: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5654600fefb0 executing computations on platform CUDA. Devices:
# 2019-06-22 22:24:14.174507: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2019-06-22 22:24:14.207012: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-06-22 22:24:14.207315: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56546016fc40 executing computations on platform Host. Devices:
# 2019-06-22 22:24:14.207457: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-22 22:24:14.207911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-22 22:24:14.208389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:04.0
# 2019-06-22 22:24:14.208505: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-06-22 22:24:14.292851: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-06-22 22:24:14.336296: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-06-22 22:24:14.351329: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-06-22 22:24:14.444190: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-06-22 22:24:14.502815: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-06-22 22:24:14.652336: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-06-22 22:24:14.652631: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-22 22:24:14.653255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-22 22:24:14.653675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-06-22 22:24:14.655257: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-06-22 22:24:16.663278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-22 22:24:16.663336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-06-22 22:24:16.663349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-06-22 22:24:16.665248: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-22 22:24:16.665825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-22 22:24:16.666289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14836 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2019-06-22 22:24:19.741779: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
#  - 5368s - loss: 0.0763 - val_loss: 0.1026
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15812     0]
#  [  188     0]]
# /home/yanke/mimic3-time-series/utils/metrics.py:23: RuntimeWarning: invalid value encountered in float_scalars
#   prec1 = cf[1][1] / (cf[1][1] + cf[0][1])
# accuracy = 0.988250017166
# precision class 0 = 0.988250017166
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.877689009425
# AUC of PRC = 0.0937795530328
# min(+P, Se) = 0.148936170213
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7822    0]
#  [ 178    0]]
# accuracy = 0.977750003338
# precision class 0 = 0.977750003338
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.778349526975
# AUC of PRC = 0.109923700526
# min(+P, Se) = 0.183574879227
#
# Epoch 00001: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk1.test0.10255486106.state
# Epoch 2/100
#  - 4736s - loss: 0.0560 - val_loss: 0.0818
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15797     0]
#  [  203     0]]
# accuracy = 0.987312495708
# precision class 0 = 0.987312495708
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.896232089962
# AUC of PRC = 0.142370354388
# min(+P, Se) = 0.221674876847
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7822    0]
#  [ 178    0]]
# accuracy = 0.977750003338
# precision class 0 = 0.977750003338
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.80990665912
# AUC of PRC = 0.155873179259
# min(+P, Se) = 0.169312169312
#
# Epoch 00002: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk2.test0.0817987405513.state
# Epoch 3/100
#  - 4726s - loss: 0.0507 - val_loss: 0.0981
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15804     0]
#  [  196     0]]
# accuracy = 0.987749993801
# precision class 0 = 0.987749993801
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.899790772421
# AUC of PRC = 0.223728317386
# min(+P, Se) = 0.24
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7816    0]
#  [ 184    0]]
# accuracy = 0.976999998093
# precision class 0 = 0.976999998093
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.83267774298
# AUC of PRC = 0.17974585181
# min(+P, Se) = 0.25
#
# Epoch 00003: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk3.test0.0981323406966.state
# Epoch 4/100
#  - 5138s - loss: 0.0527 - val_loss: 0.0780
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15810     0]
#  [  190     0]]
# accuracy = 0.988125026226
# precision class 0 = 0.988125026226
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.913200006658
# AUC of PRC = 0.223904120445
# min(+P, Se) = 0.268421052632
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7827    0]
#  [ 173    0]]
# accuracy = 0.978375017643
# precision class 0 = 0.978375017643
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.840641295767
# AUC of PRC = 0.206290313333
# min(+P, Se) = 0.261363636364
#
# Epoch 00004: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk4.test0.0779608234391.state
# Epoch 5/100
#  - 5190s - loss: 0.0473 - val_loss: 0.0909
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15802     0]
#  [  198     0]]
# accuracy = 0.987625002861
# precision class 0 = 0.987625002861
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.905592278947
# AUC of PRC = 0.227534209155
# min(+P, Se) = 0.292929292929
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7809    0]
#  [ 191    0]]
# accuracy = 0.976125001907
# precision class 0 = 0.976125001907
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.825129951412
# AUC of PRC = 0.210722785149
# min(+P, Se) = 0.259067357513
#
# Epoch 00005: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk5.test0.0908825249455.state
# Epoch 6/100
#  - 4839s - loss: 0.0460 - val_loss: 0.0920
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15807     0]
#  [  193     0]]
# accuracy = 0.987937510014
# precision class 0 = 0.987937510014
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.919526700147
# AUC of PRC = 0.224075614787
# min(+P, Se) = 0.259067357513
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7843    0]
#  [ 157    0]]
# accuracy = 0.980374991894
# precision class 0 = 0.980374991894
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.846210787988
# AUC of PRC = 0.217918329757
# min(+P, Se) = 0.22641509434
#
# Epoch 00006: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk6.test0.0920245701616.state
# Epoch 7/100
#  - 4625s - loss: 0.0518 - val_loss: 0.0844
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15795     0]
#  [  205     0]]
# accuracy = 0.987187504768
# precision class 0 = 0.987187504768
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.893993776975
# AUC of PRC = 0.201956312065
# min(+P, Se) = 0.256038647343
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7824    0]
#  [ 176    0]]
# accuracy = 0.977999985218
# precision class 0 = 0.977999985218
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.867377765384
# AUC of PRC = 0.27113167991
# min(+P, Se) = 0.323863636364
#
# Epoch 00007: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk7.test0.0843504593479.state
# Epoch 8/100
#  - 4776s - loss: 0.0515 - val_loss: 0.0873
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15774     0]
#  [  226     0]]
# accuracy = 0.98587501049
# precision class 0 = 0.98587501049
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.915102257439
# AUC of PRC = 0.204369354371
# min(+P, Se) = 0.265486725664
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7817    0]
#  [ 183    0]]
# accuracy = 0.977124989033
# precision class 0 = 0.977124989033
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.871330594452
# AUC of PRC = 0.273068919598
# min(+P, Se) = 0.338709677419
#
# Epoch 00008: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk8.test0.0872544947641.state
# Epoch 9/100
#  - 4623s - loss: 0.0484 - val_loss: 0.0909
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15788     0]
#  [  212     0]]
# accuracy = 0.986750006676
# precision class 0 = 0.986750006676
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.918493446181
# AUC of PRC = 0.259279489138
# min(+P, Se) = 0.311320754717
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7799    0]
#  [ 201    0]]
# accuracy = 0.974874973297
# precision class 0 = 0.974874973297
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.832066108743
# AUC of PRC = 0.257360968482
# min(+P, Se) = 0.298507462687
#
# Epoch 00009: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk9.test0.0908535611297.state
# Epoch 10/100
#  - 4678s - loss: 0.0539 - val_loss: 0.0767
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15809     0]
#  [  191     0]]
# accuracy = 0.988062500954
# precision class 0 = 0.988062500954
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.917414329898
# AUC of PRC = 0.246808336921
# min(+P, Se) = 0.282722513089
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7801    0]
#  [ 199    0]]
# accuracy = 0.975125014782
# precision class 0 = 0.975125014782
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.853880671142
# AUC of PRC = 0.227109645349
# min(+P, Se) = 0.291457286432
#
# Epoch 00010: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk10.test0.0766737841107.state
# Epoch 11/100
#  - 4661s - loss: 0.0491 - val_loss: 0.0935
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15806     0]
#  [  194     0]]
# accuracy = 0.987874984741
# precision class 0 = 0.987874984741
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.915958770713
# AUC of PRC = 0.220683525186
# min(+P, Se) = 0.289340101523
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7806    0]
#  [ 194    0]]
# accuracy = 0.975750029087
# precision class 0 = 0.975750029087
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.847127573027
# AUC of PRC = 0.236285263881
# min(+P, Se) = 0.268041237113
#
# Epoch 00011: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk11.test0.0935048840006.state
# Epoch 12/100
#  - 4781s - loss: 0.0446 - val_loss: 0.0802
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15792     0]
#  [  208     0]]
# accuracy = 0.986999988556
# precision class 0 = 0.986999988556
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.916247607114
# AUC of PRC = 0.263777492701
# min(+P, Se) = 0.3125
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7811    0]
#  [ 189    0]]
# accuracy = 0.976374983788
# precision class 0 = 0.976374983788
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.868403939906
# AUC of PRC = 0.256956973728
# min(+P, Se) = 0.343915343915
#
# Epoch 00012: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk12.test0.080185244629.state
# Epoch 13/100
#  - 5255s - loss: 0.0516 - val_loss: 0.0874
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15808     0]
#  [  192     0]]
# accuracy = 0.987999975681
# precision class 0 = 0.987999975681
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.892323935402
# AUC of PRC = 0.220696306327
# min(+P, Se) = 0.295336787565
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7845    0]
#  [ 155    0]]
# accuracy = 0.980624973774
# precision class 0 = 0.980624973774
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.850590678262
# AUC of PRC = 0.234272717172
# min(+P, Se) = 0.290322580645
#
# Epoch 00013: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk13.test0.0874333222891.state
# Epoch 14/100
#  - 5215s - loss: 0.0459 - val_loss: 0.0792
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15828     0]
#  [  171     1]]
# accuracy = 0.989312529564
# precision class 0 = 0.989311814308
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.00581395346671
# AUC of ROC = 0.922129277818
# AUC of PRC = 0.164710887132
# min(+P, Se) = 0.227979274611
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7819    0]
#  [ 181    0]]
# accuracy = 0.977374970913
# precision class 0 = 0.977374970913
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.863351702433
# AUC of PRC = 0.219449750369
# min(+P, Se) = 0.24861878453
#
# Epoch 00014: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk14.test0.0792435570494.state
# Epoch 15/100
#  - 5123s - loss: 0.0471 - val_loss: 0.0728
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15785     0]
#  [  214     1]]
# accuracy = 0.986625015736
# precision class 0 = 0.986624181271
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.00465116277337
# AUC of ROC = 0.912330811559
# AUC of PRC = 0.243886641345
# min(+P, Se) = 0.288372093023
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7823    0]
#  [ 176    1]]
# accuracy = 0.977999985218
# precision class 0 = 0.977997243404
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.00564971752465
# AUC of ROC = 0.855467472057
# AUC of PRC = 0.254157853777
# min(+P, Se) = 0.312849162011
#
# Epoch 00015: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk15.test0.0728192320672.state
# Epoch 16/100
#  - 4954s - loss: 0.0504 - val_loss: 0.0836
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15804     0]
#  [  196     0]]
# accuracy = 0.987749993801
# precision class 0 = 0.987749993801
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.91565604032
# AUC of PRC = 0.218645363435
# min(+P, Se) = 0.285714285714
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7846    0]
#  [ 154    0]]
# accuracy = 0.980750024319
# precision class 0 = 0.980750024319
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.85288971798
# AUC of PRC = 0.194648720542
# min(+P, Se) = 0.25974025974
#
# Epoch 00016: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk16.test0.0835600163366.state
# Epoch 17/100
#  - 4667s - loss: 0.0450 - val_loss: 0.0784
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15811     0]
#  [  189     0]]
# accuracy = 0.988187491894
# precision class 0 = 0.988187491894
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.911108534377
# AUC of PRC = 0.188379612219
# min(+P, Se) = 0.216931216931
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7822    0]
#  [ 178    0]]
# accuracy = 0.977750003338
# precision class 0 = 0.977750003338
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.869024345048
# AUC of PRC = 0.245141695062
# min(+P, Se) = 0.283333333333
#
# Epoch 00017: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk17.test0.0783771921347.state
# Epoch 18/100
#  - 4718s - loss: 0.0508 - val_loss: 0.0880
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15802     0]
#  [  198     0]]
# accuracy = 0.987625002861
# precision class 0 = 0.987625002861
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.916859552365
# AUC of PRC = 0.262185824576
# min(+P, Se) = 0.320754716981
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7813    0]
#  [ 187    0]]
# accuracy = 0.976625025272
# precision class 0 = 0.976625025272
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.872585181286
# AUC of PRC = 0.277635116628
# min(+P, Se) = 0.296296296296
#
# Epoch 00018: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk18.test0.0880326294278.state
# Epoch 19/100
#  - 4766s - loss: 0.0520 - val_loss: 0.0889
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15815     0]
#  [  185     0]]
# accuracy = 0.988437473774
# precision class 0 = 0.988437473774
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.920587536636
# AUC of PRC = 0.244799566654
# min(+P, Se) = 0.291891891892
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7851    0]
#  [ 149    0]]
# accuracy = 0.981374979019
# precision class 0 = 0.981374979019
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.849480979211
# AUC of PRC = 0.225018499649
# min(+P, Se) = 0.268456375839
#
# Epoch 00019: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk19.test0.0888976639932.state
# Epoch 20/100
#  - 4659s - loss: 0.0451 - val_loss: 0.0876
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15810     0]
#  [  190     0]]
# accuracy = 0.988125026226
# precision class 0 = 0.988125026226
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.913539232331
# AUC of PRC = 0.248916381232
# min(+P, Se) = 0.268421052632
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7805    0]
#  [ 194    1]]
# accuracy = 0.975750029087
# precision class 0 = 0.97574698925
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.0051282052882
# AUC of ROC = 0.839410962729
# AUC of PRC = 0.256555591321
# min(+P, Se) = 0.292307692308
#
# Epoch 00020: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk20.test0.0875639965667.state
# Epoch 21/100
#  - 4745s - loss: 0.0399 - val_loss: 0.0810
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15821     0]
#  [  179     0]]
# accuracy = 0.988812506199
# precision class 0 = 0.988812506199
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.927460461115
# AUC of PRC = 0.256489943744
# min(+P, Se) = 0.279329608939
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7811    0]
#  [ 188    1]]
# accuracy = 0.976499974728
# precision class 0 = 0.9764970541
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.00529100513086
# AUC of ROC = 0.875314896439
# AUC of PRC = 0.285365649071
# min(+P, Se) = 0.319796954315
#
# Epoch 00021: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk21.test0.0810001585032.state
# Epoch 22/100
#  - 4681s - loss: 0.0496 - val_loss: 0.0792
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15790     0]
#  [  210     0]]
# accuracy = 0.986874997616
# precision class 0 = 0.986874997616
# precision class 1 = nan
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.918549111855
# AUC of PRC = 0.231442211786
# min(+P, Se) = 0.3
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7820    0]
#  [ 179    1]]
# accuracy = 0.977625012398
# precision class 0 = 0.977622210979
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.00555555569008
# AUC of ROC = 0.866868783745
# AUC of PRC = 0.263394550238
# min(+P, Se) = 0.311111111111
#
# Epoch 00022: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk22.test0.0792339111319.state
# Epoch 23/100
#  - 4938s - loss: 0.0473 - val_loss: 0.0778
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15821     3]
#  [  171     5]]
# accuracy = 0.989125013351
# precision class 0 = 0.989307165146
# precision class 1 = 0.625
# recall class 0 = 0.999810397625
# recall class 1 = 0.0284090917557
# AUC of ROC = 0.924083239498
# AUC of PRC = 0.221934695308
# min(+P, Se) = 0.278409090909
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7850    0]
#  [ 149    1]]
# accuracy = 0.981374979019
# precision class 0 = 0.981372654438
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.0066666668281
# AUC of ROC = 0.84284670913
# AUC of PRC = 0.238730637171
# min(+P, Se) = 0.282894736842
#
# Epoch 00023: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk23.test0.077806024389.state
# Epoch 24/100
#  - 5266s - loss: 0.0493 - val_loss: 0.0783
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15808     1]
#  [  188     3]]
# accuracy = 0.988187491894
# precision class 0 = 0.988247036934
# precision class 1 = 0.75
# recall class 0 = 0.999936759472
# recall class 1 = 0.0157068055123
# AUC of ROC = 0.921384167478
# AUC of PRC = 0.300048937091
# min(+P, Se) = 0.326424870466
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7811    0]
#  [ 186    3]]
# accuracy = 0.976750016212
# precision class 0 = 0.97674125433
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.0158730167896
# AUC of ROC = 0.827678236973
# AUC of PRC = 0.248233722837
# min(+P, Se) = 0.296296296296
#
# Epoch 00024: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk24.test0.0783392358216.state
# Epoch 25/100
#  - 5237s - loss: 0.0485 - val_loss: 0.0797
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15823     7]
#  [  157    13]]
# accuracy = 0.989750027657
# precision class 0 = 0.990175247192
# precision class 1 = 0.649999976158
# recall class 0 = 0.99955779314
# recall class 1 = 0.0764705911279
# AUC of ROC = 0.909661290922
# AUC of PRC = 0.212749262751
# min(+P, Se) = 0.271676300578
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7819    5]
#  [ 159   17]]
# accuracy = 0.979499995708
# precision class 0 = 0.98007017374
# precision class 1 = 0.772727251053
# recall class 0 = 0.999360918999
# recall class 1 = 0.0965909063816
# AUC of ROC = 0.874836604155
# AUC of PRC = 0.283490256132
# min(+P, Se) = 0.306818181818
#
# Epoch 00025: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk25.test0.0797339338367.state
# Epoch 26/100
#  - 5181s - loss: 0.0551 - val_loss: 0.0886
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15813     2]
#  [  181     4]]
# accuracy = 0.988562524319
# precision class 0 = 0.988683283329
# precision class 1 = 0.666666686535
# recall class 0 = 0.999873518944
# recall class 1 = 0.0216216221452
# AUC of ROC = 0.925877075305
# AUC of PRC = 0.237100416535
# min(+P, Se) = 0.286486486486
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7824    0]
#  [ 174    2]]
# accuracy = 0.978250026703
# precision class 0 = 0.978244543076
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.0113636367023
# AUC of ROC = 0.86223115937
# AUC of PRC = 0.243916480082
# min(+P, Se) = 0.295081967213
#
# Epoch 00026: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk26.test0.0886476493621.state
# Epoch 27/100
#  - 5111s - loss: 0.0427 - val_loss: 0.0835
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15824     2]
#  [  165     9]]
# accuracy = 0.989562511444
# precision class 0 = 0.989680409431
# precision class 1 = 0.818181812763
# recall class 0 = 0.999873638153
# recall class 1 = 0.051724139601
# AUC of ROC = 0.920323169642
# AUC of PRC = 0.276112372991
# min(+P, Se) = 0.310344827586
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7814    3]
#  [ 179    4]]
# accuracy = 0.977249979973
# precision class 0 = 0.97760540247
# precision class 1 = 0.571428596973
# recall class 0 = 0.999616205692
# recall class 1 = 0.0218579228967
# AUC of ROC = 0.868519361263
# AUC of PRC = 0.25471538952
# min(+P, Se) = 0.300546448087
#
# Epoch 00027: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk27.test0.0835051888945.state
# Epoch 28/100
#  - 5094s - loss: 0.0455 - val_loss: 0.0992
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15806     1]
#  [  179    14]]
# accuracy = 0.988749980927
# precision class 0 = 0.988802015781
# precision class 1 = 0.933333337307
# recall class 0 = 0.999936759472
# recall class 1 = 0.0725388601422
# AUC of ROC = 0.921401156633
# AUC of PRC = 0.297446117141
# min(+P, Se) = 0.309278350515
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7826    5]
#  [ 164    5]]
# accuracy = 0.978874981403
# precision class 0 = 0.979474365711
# precision class 1 = 0.5
# recall class 0 = 0.999361515045
# recall class 1 = 0.0295857992023
# AUC of ROC = 0.877735581315
# AUC of PRC = 0.256892515082
# min(+P, Se) = 0.313609467456
#
# Epoch 00028: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk28.test0.0992203795986.state
# Epoch 29/100
#  - 5209s - loss: 0.0449 - val_loss: 0.0832
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15794     3]
#  [  185    18]]
# accuracy = 0.988250017166
# precision class 0 = 0.98842227459
# precision class 1 = 0.857142865658
# recall class 0 = 0.999810099602
# recall class 1 = 0.0886699482799
# AUC of ROC = 0.931993541207
# AUC of PRC = 0.30934416994
# min(+P, Se) = 0.31884057971
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7826    1]
#  [ 164    9]]
# accuracy = 0.979375004768
# precision class 0 = 0.979474365711
# precision class 1 = 0.899999976158
# recall class 0 = 0.999872207642
# recall class 1 = 0.0520231202245
# AUC of ROC = 0.849348372427
# AUC of PRC = 0.261957077405
# min(+P, Se) = 0.308571428571
#
# Epoch 00029: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk29.test0.0831928411218.state
# Epoch 30/100
#  - 5167s - loss: 0.0473 - val_loss: 0.0845
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15811     0]
#  [  185     4]]
# accuracy = 0.988437473774
# precision class 0 = 0.988434612751
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.0211640205234
# AUC of ROC = 0.923082817903
# AUC of PRC = 0.299809669677
# min(+P, Se) = 0.333333333333
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7820    2]
#  [ 178    0]]
# accuracy = 0.977500021458
# precision class 0 = 0.977744460106
# precision class 1 = 0.0
# recall class 0 = 0.999744296074
# recall class 1 = 0.0
# AUC of ROC = 0.84512998486
# AUC of PRC = 0.205994542245
# min(+P, Se) = 0.251396648045
#
# Epoch 00030: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk30.test0.0844665352663.state
# Epoch 31/100
#  - 5110s - loss: 0.0485 - val_loss: 0.0782
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15822     1]
#  [  167    10]]
# accuracy = 0.989499986172
# precision class 0 = 0.989555299282
# precision class 1 = 0.909090936184
# recall class 0 = 0.999936819077
# recall class 1 = 0.0564971752465
# AUC of ROC = 0.909410816194
# AUC of PRC = 0.245961878321
# min(+P, Se) = 0.271186440678
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7823    2]
#  [ 156   19]]
# accuracy = 0.980250000954
# precision class 0 = 0.980448663235
# precision class 1 = 0.904761910439
# recall class 0 = 0.999744415283
# recall class 1 = 0.10857142508
# AUC of ROC = 0.872912460064
# AUC of PRC = 0.317624400604
# min(+P, Se) = 0.32967032967
#
# Epoch 00031: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk31.test0.0781914434265.state
# Epoch 32/100
#  - 4570s - loss: 0.0468 - val_loss: 0.0771
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15798     8]
#  [  177    17]]
# accuracy = 0.988437473774
# precision class 0 = 0.988920211792
# precision class 1 = 0.680000007153
# recall class 0 = 0.999493837357
# recall class 1 = 0.0876288637519
# AUC of ROC = 0.915562862074
# AUC of PRC = 0.251190976444
# min(+P, Se) = 0.314432989691
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7817    5]
#  [ 161   17]]
# accuracy = 0.979250013828
# precision class 0 = 0.979819476604
# precision class 1 = 0.772727251053
# recall class 0 = 0.999360799789
# recall class 1 = 0.095505617559
# AUC of ROC = 0.851795856688
# AUC of PRC = 0.26426063589
# min(+P, Se) = 0.297752808989
#
# Epoch 00032: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk32.test0.0770712060675.state
# Epoch 33/100
#  - 4625s - loss: 0.0508 - val_loss: 0.0777
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15777     3]
#  [  208    12]]
# accuracy = 0.986812472343
# precision class 0 = 0.986987829208
# precision class 1 = 0.800000011921
# recall class 0 = 0.999809861183
# recall class 1 = 0.0545454546809
# AUC of ROC = 0.929322646618
# AUC of PRC = 0.299778177306
# min(+P, Se) = 0.303167420814
#
# ==>predicting on validation
# confusion matrix:
# [[7824    4]
#  [ 157   15]]
# accuracy = 0.979875028133
# precision class 0 = 0.980328261852
# precision class 1 = 0.789473712444
# recall class 0 = 0.99948900938
# recall class 1 = 0.0872092992067
# AUC of ROC = 0.875619793585
# AUC of PRC = 0.2621474718
# min(+P, Se) = 0.297142857143
#
# Epoch 00033: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk33.test0.077742607558.state
# Epoch 34/100
#  - 4609s - loss: 0.0466 - val_loss: 0.0882
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15811     2]
#  [  179     8]]
# accuracy = 0.988687515259
# precision class 0 = 0.988805532455
# precision class 1 = 0.800000011921
# recall class 0 = 0.999873518944
# recall class 1 = 0.0427807494998
# AUC of ROC = 0.914507321702
# AUC of PRC = 0.253871936644
# min(+P, Se) = 0.299465240642
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7825    0]
#  [ 169    6]]
# accuracy = 0.978874981403
# precision class 0 = 0.978859126568
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.0342857129872
# AUC of ROC = 0.880134002738
# AUC of PRC = 0.293497898071
# min(+P, Se) = 0.291428571429
#
# Epoch 00034: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk34.test0.0882005460003.state
# Epoch 35/100
#  - 4704s - loss: 0.0403 - val_loss: 0.0775
#
# ==>predicting on train
#
#
# confusion matrix:
# [[15793     7]
#  [  188    12]]
# accuracy = 0.987812519073
# precision class 0 = 0.988236010075
# precision class 1 = 0.631578922272
# recall class 0 = 0.999556958675
# recall class 1 = 0.0599999986589
# AUC of ROC = 0.914476740506
# AUC of PRC = 0.268944910977
# min(+P, Se) = 0.32
#
# ==>predicting on validation
#
#
# confusion matrix:
# [[7834    2]
#  [ 158    6]]
# accuracy = 0.980000019073
# precision class 0 = 0.980230212212
# precision class 1 = 0.75
# recall class 0 = 0.999744772911
# recall class 1 = 0.0365853644907
# AUC of ROC = 0.856648566964
# AUC of PRC = 0.223335822269
# min(+P, Se) = 0.287425149701
#
# Epoch 00035: saving model to decompensation/keras_states/k_lstm.n16.d0.3.dep2.bs8.ts1.0.chunk35.test0.0775409132059.state
